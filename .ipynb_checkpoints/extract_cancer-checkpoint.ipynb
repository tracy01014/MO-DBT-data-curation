# %%
import pandas as pd
import os
import numpy as np
import re

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # <span style="color:blue;">**Cancer**</span>

# %%
study = "Cancer"

# %% [markdown]
# # Data preparation

# %% [markdown]
# ## A. DICOM

# %% [markdown]
# #### Visit [parameter exlanation][peid] for more information
#
# [peid]: https://pitt-my.sharepoint.com/:w:/r/personal/trl117_pitt_edu/_layouts/15/Doc.aspx?sourcedoc=%7B7B05A758-0D43-40AF-9177-E9C7522D2649%7D&file=Notes_parameters%20explaination.docx&action=default&mobileredirect=true

# %%
file_path = "../Data/dicom_tag.xlsx"
dicom = pd.read_excel(file_path)

# %%
dicom["PatientID"].unique().size
# Out:
# 5515

# %%
PIDs = dicom["PatientID"].unique()

# %% [markdown]
# #### Create a list of unique DICOM entries to serve as the reference linking the EHR to the images available for specific patient visits (as images are limited to certain visits, not all).
#
# #### See shared parameters in [parameter exlanation][peid] to link data
#
# [peid]: https://pitt-my.sharepoint.com/:w:/r/personal/trl117_pitt_edu/_layouts/15/Doc.aspx?sourcedoc=%7B7B05A758-0D43-40AF-9177-E9C7522D2649%7D&file=Notes_parameters%20explaination.docx&action=default&mobileredirect=true

# %% [markdown]
# **shared parameters:**
#
# DICOM ↔︎ EHR (pathology)
#
# PatientID ↔︎ PATIENT_STUDY_ID
#
# AccessionNumber ↔︎ ACCESSION_NUMBER
#
# PatientBirthDate ↔︎ BIRTH_DATE

# %%
dicom.rename(columns={'PatientID': 'PATIENT_STUDY_ID', 'AccessionNumber': 'ACCESSION_NUMBER', 'PatientBirthDate': 'BIRTH_DATE'}, inplace=True)

# %%
dicom
# Out:
#         PATIENT_STUDY_ID  ACCESSION_NUMBER  BIRTH_DATE PatientAge PatientSex  \
# 0             4330018595          60103700  1965-07-01       054Y          F
# 1             4330018595          60103700  1965-07-01        NaN          F
# 2             4330018595          60103700  1965-07-01        NaN          F
# 3             4330018595          60103700  1965-07-01        NaN          F
# 4             4330018595          60103700  1965-07-01        NaN          F
# ...                  ...               ...         ...        ...        ...
# 136228        4339959661          62216536  1971-07-01        NaN          F
# 136229        4339959661          62216536  1971-07-01        NaN          F
# 136230        4339959661          62216536  1971-07-01        NaN          F
# 136231        4339959661          62216536  1971-07-01        NaN          F
# 136232        4339959661          62216536  1971-07-01        NaN          F
#
#          StudyDate StudyTime AcquisitionDate Modality  \
# 0       2020-06-02  09:10:52             NaN       MG
# 1       2020-06-02  09:10:51             NaN       MG
# 2       2020-06-02  09:10:51      2020-06-02       MG
# 3       2020-06-02  09:10:51             NaN       MG
# 4       2020-06-02  09:10:51             NaN       MG
# ...            ...       ...             ...      ...
# 136228  2019-10-28  02:45:37      2019-10-28       MG
# 136229  2019-10-28  02:45:37      2019-10-28       MG
# 136230  2019-10-28  02:45:37      2019-10-28       MG
# 136231  2019-10-28  18:20:08             NaN       PR
# 136232  2019-10-28  18:20:08             NaN       PR
#
#                    Manufacturer ManufacturerModelName  \
# 0           R2 Technology, Inc.                Cenova
# 1           R2 Technology, Inc.                Cenova
# 2                 HOLOGIC, Inc.    Selenia Dimensions
# 3                 HOLOGIC, Inc.    Selenia Dimensions
# 4                 HOLOGIC, Inc.    Selenia Dimensions
# ...                         ...                   ...
# 136228            HOLOGIC, Inc.    Selenia Dimensions
# 136229            HOLOGIC, Inc.    Selenia Dimensions
# 136230            HOLOGIC, Inc.    Selenia Dimensions
# 136231  Philips Medical Systems      iSite Enterprise
# 136232  Philips Medical Systems      iSite Enterprise
#
#                                          StudyDescription  SeriesNumber  \
# 0       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS           1.0
# 1       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS           1.0
# 2       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS    71100000.0
# 3       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS    71300000.0
# 4       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS    71300000.0
# ...                                                   ...           ...
# 136228  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN    72100000.0
# 136229  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN    72100000.0
# 136230  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN    72100000.0
# 136231  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN           1.0
# 136232  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN           1.0
#
#                      SeriesDescription  Exposure    Rows  Columns  \
# 0       Hologic R2 ImageChecker CAD SC       NaN  1500.0   1250.0
# 1       Hologic R2 ImageChecker CAD SC       NaN  1500.0   1250.0
# 2                                 R ML     126.0  3328.0   2560.0
# 3                R XCCL Intelligent 2D      63.0  3328.0   2560.0
# 4                  R ML Intelligent 2D      57.0  3328.0   2560.0
# ...                                ...       ...     ...      ...
# 136228   L CC Tomosynthesis Projection      72.0   425.0    266.0
# 136229   R CC Tomosynthesis Projection      74.0   425.0    266.0
# 136230  L MLO Tomosynthesis Projection      78.0   425.0    266.0
# 136231                       5DBAD14E0       NaN     NaN      NaN
# 136232                       5DBAD14E0       NaN     NaN      NaN
#
#              PixelSpacing   study side series
# 0                     NaN    DIAG  NaN    NaN
# 1                     NaN    DIAG  NaN    NaN
# 2       0.038889\0.038889    DIAG    R    NaN
# 3       0.064318\0.064318    DIAG    R   IN2D
# 4       0.064619\0.064619    DIAG    R   IN2D
# ...                   ...     ...  ...    ...
# 136228                NaN  SCREEN    L    DBT
# 136229                NaN  SCREEN    R    DBT
# 136230                NaN  SCREEN    L    DBT
# 136231                NaN  SCREEN  NaN    NaN
# 136232                NaN  SCREEN  NaN    NaN
#
# [136233 rows x 21 columns]

# %%
# Define the key identifier columns and columns to extract
key_columns = ['PATIENT_STUDY_ID', 'ACCESSION_NUMBER', 'StudyDate', 'BIRTH_DATE', 'PatientSex']
extract_columns = ['PATIENT_STUDY_ID', 'ACCESSION_NUMBER', 'StudyDate', 'StudyTime', 'study']
unique_dicom = dicom.drop_duplicates(subset=key_columns, keep='first')
unique_dicom = unique_dicom[extract_columns]
unique_dicom.reset_index(drop=True, inplace=True)

# %%
unique_dicom['image_available'] = 1

# %%
unique_dicom
# Out:
#        PATIENT_STUDY_ID  ACCESSION_NUMBER   StudyDate StudyTime   study  \
# 0            4330018595          60103700  2020-06-02  09:10:52    DIAG
# 1            4330018595          60690108  2020-06-02  08:33:36  SCREEN
# 2            4330018595          63737104  2019-08-19  02:11:20    DIAG
# 3            4330029102          64888584  2019-05-16  08:32:09  SCREEN
# 4            4330044371          61647696  2020-02-06  15:37:19  SCREEN
# ...                 ...               ...         ...       ...     ...
# 15135        4339943307          63434181  2019-06-17  17:07:31    DIAG
# 15136        4339943307          63570279  2019-05-23  18:36:05  SCREEN
# 15137        4339945522          62906727  2019-10-18  03:00:54    DIAG
# 15138        4339945522         450264459  2022-10-14  11:54:03     NaN
# 15139        4339959661          62216536  2019-10-28  02:45:37  SCREEN
#
#        image_available
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 15135                1
# 15136                1
# 15137                1
# 15138                1
# 15139                1
#
# [15140 rows x 6 columns]

# %% [markdown]
# #### Add "dbt_available" column, if available = 1

# %%
dicom_DBT = dicom[dicom["series"]=="DBT"]
key_columns = ['PATIENT_STUDY_ID', 'ACCESSION_NUMBER', 'StudyDate', 'BIRTH_DATE', 'PatientSex']
extract_columns = ['PATIENT_STUDY_ID', 'ACCESSION_NUMBER', 'StudyDate', 'study', 'series']
unique_dicom_DBT = dicom_DBT.drop_duplicates(subset=key_columns, keep='first')[extract_columns]

# %%
unique_dicom = unique_dicom.merge(
    unique_dicom_DBT, 
    on=['PATIENT_STUDY_ID', 'ACCESSION_NUMBER', 'StudyDate', 'study'],
    how='left')

# %%
unique_dicom = unique_dicom.rename(columns={'series': 'dbt_available'})
unique_dicom['dbt_available'] = unique_dicom['dbt_available'].replace('DBT', 1)
# Out:
# /var/folders/g9/k5r102q54f126nrlr692zy6c0000gn/T/ipykernel_35586/3012130192.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   unique_dicom['dbt_available'] = unique_dicom['dbt_available'].replace('DBT', 1)

# %%
unique_dicom
# Out:
#        PATIENT_STUDY_ID  ACCESSION_NUMBER   StudyDate StudyTime   study  \
# 0            4330018595          60103700  2020-06-02  09:10:52    DIAG
# 1            4330018595          60690108  2020-06-02  08:33:36  SCREEN
# 2            4330018595          63737104  2019-08-19  02:11:20    DIAG
# 3            4330029102          64888584  2019-05-16  08:32:09  SCREEN
# 4            4330044371          61647696  2020-02-06  15:37:19  SCREEN
# ...                 ...               ...         ...       ...     ...
# 15135        4339943307          63434181  2019-06-17  17:07:31    DIAG
# 15136        4339943307          63570279  2019-05-23  18:36:05  SCREEN
# 15137        4339945522          62906727  2019-10-18  03:00:54    DIAG
# 15138        4339945522         450264459  2022-10-14  11:54:03     NaN
# 15139        4339959661          62216536  2019-10-28  02:45:37  SCREEN
#
#        image_available  dbt_available
# 0                    1            NaN
# 1                    1            NaN
# 2                    1            NaN
# 3                    1            NaN
# 4                    1            NaN
# ...                ...            ...
# 15135                1            NaN
# 15136                1            NaN
# 15137                1            NaN
# 15138                1            NaN
# 15139                1            1.0
#
# [15140 rows x 7 columns]

# %% [markdown]
# ## B. Electric Health Record

# %% [markdown]
# #### Visit [parameter exlanation][peid] for more information
#
# [peid]: https://pitt-my.sharepoint.com/:w:/r/personal/trl117_pitt_edu/_layouts/15/Doc.aspx?sourcedoc=%7B7B05A758-0D43-40AF-9177-E9C7522D2649%7D&file=Notes_parameters%20explaination.docx&action=default&mobileredirect=true

# %%
file_path = "../Data/parameters of interest.xlsx"
file_name = pd.ExcelFile(file_path).sheet_names
file_name
# Out:
# ['pathology',
#  'pathology_findings',
#  'patient_data_ie',
#  'family_hx',
#  'patient_demo',
#  'vitals',
#  'risk_factors',
#  'enteredit_findings',
#  'hormonal_mens']

# %% [markdown]
# ---

# %% [markdown]
# # I. Extract <span style="color:blue;">**Cancer**</span>
# #### output file = "cancer_cohort", N=1956

# %% [markdown]
# #### See [inclusion criteria][ic] to for filtering
#
# [ic]: https://pitt-my.sharepoint.com/:w:/r/personal/trl117_pitt_edu/_layouts/15/doc.aspx?sourcedoc=%7B9c403413-a771-4830-98ab-15171872c4dd%7D&action=edit

# %% [markdown]
# ## 1. Merge with enteredit_findings

# %% [markdown]
# * Columns: COMPOSITION_NAME, FINDING_LOCATION, FINDING_CATEGORY, FINDING_REC, EXAM_COMPLETED_DATE
# * Cancer:
#     * FINDING_CATEGORY = 4, 4A, 4B, 4C, 5

# %%
fn = file_name[7]
fn
# Out:
# 'enteredit_findings'

# %%
file_path = os.path.join("../Data/", study, "Cleaned", fn + ".xlsx")
BIRADS = pd.read_excel(file_path)

# %%
set_dicom_PIDs = set(PIDs)
set_BIRADS_PIDs = set(BIRADS["PATIENT_STUDY_ID"].unique())

common_PIDs = set_dicom_PIDs & set_BIRADS_PIDs

# %%
len(common_PIDs)
# Out:
# 5509

# %%
unique_dicom[unique_dicom["PATIENT_STUDY_ID"]==4330344296]
# Out:
#     PATIENT_STUDY_ID  ACCESSION_NUMBER   StudyDate StudyTime   study  \
# 66        4330344296          62861703  2019-12-20  02:44:43  SCREEN
# 67        4330344296          67469599  2020-12-31  08:39:44  SCREEN
# 68        4330344296          71644307  2017-07-31  02:23:29  SCREEN
# 69        4330344296          76610889  2018-10-31  16:35:19  SCREEN
# 70        4330344296          76695188  2018-11-08  15:23:00    DIAG
#
#     image_available  dbt_available
# 66                1            NaN
# 67                1            NaN
# 68                1            NaN
# 69                1            NaN
# 70                1            NaN

# %%
BIRADS[BIRADS["PATIENT_STUDY_ID"]==4330344296]
# Out:
#      PATIENT_STUDY_ID  ACCESSION_NUMBER                   COMPOSITION_NAME  \
# 402        4330344296          71644307  Heterogeneously dense (51% - 75%)
# 403        4330344296          76610889  Heterogeneously dense (51% - 75%)
# 404        4330344296          76610889  Heterogeneously dense (51% - 75%)
# 405        4330344296          76695188  Heterogeneously dense (51% - 75%)
# 406        4330344296          62861703  Heterogeneously dense (51% - 75%)
# 407        4330344296          67469599  Heterogeneously dense (51% - 75%)
# 408        4330344296          67469599  Heterogeneously dense (51% - 75%)
# 409        4330344296          67156697  Heterogeneously dense (51% - 75%)
# 410        4330344296         453737129  Heterogeneously dense (51% - 75%)
#
#     FINDING_LOCATION                                   FINDING_CATEGORY  \
# 402              NaN                                 2 - Benign finding
# 403              NaN             0 - Need additional imaging evaluation
# 404              NaN                                       1 - Negative
# 405              NaN                                 2 - Benign finding
# 406              NaN                                 2 - Benign finding
# 407              NaN             0 - Need additional imaging evaluation
# 408              NaN                                       1 - Negative
# 409              NaN  4A - Suspicious abnormality - biopsy should be...
# 410              NaN                                 2 - Benign finding
#
#                        FINDING_REC EXAM_COMPLETED_DATE  duplicate_count
# 402    N-Normal interval follow-up          2017-07-31                2
# 403       P-Additional projections          2018-10-31                1
# 404    N-Normal interval follow-up          2018-10-31                1
# 405    N-Normal interval follow-up          2018-11-08                1
# 406    N-Normal interval follow-up          2019-12-20                2
# 407       P-Additional projections          2020-12-31                1
# 408    N-Normal interval follow-up          2020-12-31                1
# 409  B-Biopsy should be considered          2021-01-25                2
# 410    N-Normal interval follow-up          2022-02-10                1

# %%
merge = pd.merge(
    BIRADS, 
    unique_dicom,
    on=['PATIENT_STUDY_ID', 'ACCESSION_NUMBER'], 
    how='left'
)

# %%
merge[merge["PATIENT_STUDY_ID"]==4330344296]
# Out:
#      PATIENT_STUDY_ID  ACCESSION_NUMBER                   COMPOSITION_NAME  \
# 404        4330344296          71644307  Heterogeneously dense (51% - 75%)
# 405        4330344296          76610889  Heterogeneously dense (51% - 75%)
# 406        4330344296          76610889  Heterogeneously dense (51% - 75%)
# 407        4330344296          76695188  Heterogeneously dense (51% - 75%)
# 408        4330344296          62861703  Heterogeneously dense (51% - 75%)
# 409        4330344296          67469599  Heterogeneously dense (51% - 75%)
# 410        4330344296          67469599  Heterogeneously dense (51% - 75%)
# 411        4330344296          67156697  Heterogeneously dense (51% - 75%)
# 412        4330344296         453737129  Heterogeneously dense (51% - 75%)
#
#     FINDING_LOCATION                                   FINDING_CATEGORY  \
# 404              NaN                                 2 - Benign finding
# 405              NaN             0 - Need additional imaging evaluation
# 406              NaN                                       1 - Negative
# 407              NaN                                 2 - Benign finding
# 408              NaN                                 2 - Benign finding
# 409              NaN             0 - Need additional imaging evaluation
# 410              NaN                                       1 - Negative
# 411              NaN  4A - Suspicious abnormality - biopsy should be...
# 412              NaN                                 2 - Benign finding
#
#                        FINDING_REC EXAM_COMPLETED_DATE  duplicate_count  \
# 404    N-Normal interval follow-up          2017-07-31                2
# 405       P-Additional projections          2018-10-31                1
# 406    N-Normal interval follow-up          2018-10-31                1
# 407    N-Normal interval follow-up          2018-11-08                1
# 408    N-Normal interval follow-up          2019-12-20                2
# 409       P-Additional projections          2020-12-31                1
# 410    N-Normal interval follow-up          2020-12-31                1
# 411  B-Biopsy should be considered          2021-01-25                2
# 412    N-Normal interval follow-up          2022-02-10                1
#
#       StudyDate StudyTime   study  image_available  dbt_available
# 404  2017-07-31  02:23:29  SCREEN              1.0            NaN
# 405  2018-10-31  16:35:19  SCREEN              1.0            NaN
# 406  2018-10-31  16:35:19  SCREEN              1.0            NaN
# 407  2018-11-08  15:23:00    DIAG              1.0            NaN
# 408  2019-12-20  02:44:43  SCREEN              1.0            NaN
# 409  2020-12-31  08:39:44  SCREEN              1.0            NaN
# 410  2020-12-31  08:39:44  SCREEN              1.0            NaN
# 411         NaN       NaN     NaN              NaN            NaN
# 412         NaN       NaN     NaN              NaN            NaN

# %%
merge_copy = merge[merge["PATIENT_STUDY_ID"].isin(PIDs)].copy()

# %%
merge_copy["PATIENT_STUDY_ID"].unique().size
# Out:
# 5509

# %% [markdown]
# ## 2. Merge with pathology

# %% [markdown]
# ### preparation: sort by dates

# %% [markdown]
# * Columns: BX_ID, PATHOLOGY_DATE, LESION_CLASS, SIDE
# * Cancer:
#     * LESION_CLASS = 'Malignant'

# %%
fn = file_name[0]
fn
# Out:
# 'pathology'

# %%
file_path = os.path.join("../Data/", study, "Cleaned", fn + ".xlsx")
pathology = pd.read_excel(file_path)

# %%
pathology_sort = pathology.copy()
merge_sort = merge_copy.copy()

pathology_sort['PATHOLOGY_DATE'] = pd.to_datetime(pathology_sort['PATHOLOGY_DATE'])
merge_sort['EXAM_COMPLETED_DATE'] = pd.to_datetime(merge_sort['EXAM_COMPLETED_DATE'])

pathology_sort.sort_values(by =['PATIENT_STUDY_ID', 'PATHOLOGY_DATE'],inplace=True)
merge_sort.sort_values(by =['PATIENT_STUDY_ID', 'EXAM_COMPLETED_DATE'],inplace=True)

# %% [markdown]
# ### Store <span style="color:blue;">**cancer**</span> record only

# %% [markdown]
# #### For each patient, find if LESION_CLASS = 'Malignant' ever exists in their records, and only store the record with 'Malignant' findings.**

# %%
cancer_cohort = None
PIDs_without_pathology = []
PIDs_without_malignant = []
PIDs_with_malignant = []

for pid in PIDs:
    
    # merge_asof can only deal with one patient ID at a time, and the date needs to be sorted ascending
    
    path = pathology_sort[pathology_sort["PATIENT_STUDY_ID"]==pid]
    merg = merge_sort[merge_sort["PATIENT_STUDY_ID"]==pid]
    
    if path.size == 0:
        
        PIDs_without_pathology.append(pid)
#         print("skip")
    
    else:
    
        closest_match = pd.merge_asof(
        left=path,
        right=merg,
        left_on='PATHOLOGY_DATE',          # The date we are matching FROM
        right_on='EXAM_COMPLETED_DATE',    # The date we are matching TO
        by='PATIENT_STUDY_ID',             # The grouping key (Int64)
        direction='backward',             # Finds the closest date (after)
        allow_exact_matches=True,
        tolerance=pd.Timedelta(days=365)   # maximum time interval to be considered
        )
        
        
        # Check if LESION_CLASS = 'Malignant' ever exsits for the patient, if none, skip
        column_to_check = 'LESION_CLASS' 
        closest_match[column_to_check] = closest_match[column_to_check].astype(str)
        lesion_terms = 'Malignant'
        lesion_mask = closest_match[column_to_check].str.contains(lesion_terms, case=False, na=False, regex=True)
        
        if closest_match.loc[lesion_mask].size==0: 
            PIDs_without_malignant.append(pid)
#             print("no malignant")
        else:
            PIDs_with_malignant.append(pid)
            combine = merg.merge(closest_match, how='outer')
            cancer_cohort = pd.concat([cancer_cohort, combine])

# %%
cancer_cohort.reset_index(inplace=True, drop=True)
print("‼️ # of patients without pathology:", len(PIDs_without_pathology))
print("‼️ # of patients with pathology:", len(PIDs_without_malignant)+len(PIDs_with_malignant))
print("‼️ # of patients without malignant:",len(PIDs_without_malignant))
print("‼️ # of patients with malignant:",len(PIDs_with_malignant))
# Out:
# ‼️ # of patients without pathology: 305
# ‼️ # of patients with pathology: 5210
# ‼️ # of patients without malignant: 3254
# ‼️ # of patients with malignant: 1956

# %%
cancer_cohort_sort = cancer_cohort.sort_values(['PATIENT_STUDY_ID', 'EXAM_COMPLETED_DATE', 'ACCESSION_NUMBER']).reset_index(drop=True)

# %%
cancer_cohort_sort[cancer_cohort_sort["PATIENT_STUDY_ID"]==4330344296]
# Out:
#      PATIENT_STUDY_ID  ACCESSION_NUMBER                   COMPOSITION_NAME  \
# 108        4330344296        71644307.0  Heterogeneously dense (51% - 75%)
# 109        4330344296        76610889.0  Heterogeneously dense (51% - 75%)
# 110        4330344296        76610889.0  Heterogeneously dense (51% - 75%)
# 111        4330344296        76695188.0  Heterogeneously dense (51% - 75%)
# 112        4330344296        62861703.0  Heterogeneously dense (51% - 75%)
# 113        4330344296        67469599.0  Heterogeneously dense (51% - 75%)
# 114        4330344296        67469599.0  Heterogeneously dense (51% - 75%)
# 115        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 116        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 117        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 118        4330344296       453737129.0  Heterogeneously dense (51% - 75%)
#
#     FINDING_LOCATION                                   FINDING_CATEGORY  \
# 108              NaN                                 2 - Benign finding
# 109              NaN             0 - Need additional imaging evaluation
# 110              NaN                                       1 - Negative
# 111              NaN                                 2 - Benign finding
# 112              NaN                                 2 - Benign finding
# 113              NaN             0 - Need additional imaging evaluation
# 114              NaN                                       1 - Negative
# 115              NaN  4A - Suspicious abnormality - biopsy should be...
# 116              NaN  4A - Suspicious abnormality - biopsy should be...
# 117              NaN  4A - Suspicious abnormality - biopsy should be...
# 118              NaN                                 2 - Benign finding
#
#                        FINDING_REC EXAM_COMPLETED_DATE  duplicate_count  \
# 108    N-Normal interval follow-up          2017-07-31              2.0
# 109       P-Additional projections          2018-10-31              1.0
# 110    N-Normal interval follow-up          2018-10-31              1.0
# 111    N-Normal interval follow-up          2018-11-08              1.0
# 112    N-Normal interval follow-up          2019-12-20              2.0
# 113       P-Additional projections          2020-12-31              1.0
# 114    N-Normal interval follow-up          2020-12-31              1.0
# 115  B-Biopsy should be considered          2021-01-25              2.0
# 116  B-Biopsy should be considered          2021-01-25              2.0
# 117  B-Biopsy should be considered          2021-01-25              2.0
# 118    N-Normal interval follow-up          2022-02-10              1.0
#
#       StudyDate StudyTime   study  image_available  dbt_available     BX_ID  \
# 108  2017-07-31  02:23:29  SCREEN              1.0            NaN       NaN
# 109  2018-10-31  16:35:19  SCREEN              1.0            NaN       NaN
# 110  2018-10-31  16:35:19  SCREEN              1.0            NaN       NaN
# 111  2018-11-08  15:23:00    DIAG              1.0            NaN       NaN
# 112  2019-12-20  02:44:43  SCREEN              1.0            NaN       NaN
# 113  2020-12-31  08:39:44  SCREEN              1.0            NaN       NaN
# 114  2020-12-31  08:39:44  SCREEN              1.0            NaN       NaN
# 115         NaN       NaN     NaN              NaN            NaN  470168.0
# 116         NaN       NaN     NaN              NaN            NaN  470167.0
# 117         NaN       NaN     NaN              NaN            NaN  478775.0
# 118         NaN       NaN     NaN              NaN            NaN       NaN
#
#     PATHOLOGY_DATE LESION_CLASS SIDE
# 108            NaT          NaN  NaN
# 109            NaT          NaN  NaN
# 110            NaT          NaN  NaN
# 111            NaT          NaN  NaN
# 112            NaT          NaN  NaN
# 113            NaT          NaN  NaN
# 114            NaT          NaN  NaN
# 115     2021-02-10    Malignant    R
# 116     2021-02-10       Benign    R
# 117     2021-03-05    Malignant    R
# 118            NaT          NaN  NaN

# %%
output_file = os.path.join("../Data/", study, 'cancer_cohort' + ".xlsx")
cancer_cohort_sort.to_excel(output_file, index=False)

# %% [markdown]
# ## 3. Fill missing <span style="color:blue"> **Study**</span> (SCREEN, DIAG) with patient_data_ie

# %% [markdown]
# #### <span style="color:#FF6347;">**READ**</span> file

# %%
file_path = "../Data/Cancer/cancer_cohort.xlsx"
cancer_cohort = pd.read_excel(file_path)

# %%
file_path = "../Data/Cancer/patient_data_ie_tag.xlsx"
pdi = pd.read_excel(file_path)

# %%
pdi.columns
# Out:
# Index(['PATIENT_STUDY_ID', 'ACCESSION_NUMBER', 'ORG_NAME', 'EXAM_CODE',
#        'EXAM_NAME', 'COMPLETED_DATE', 'ORDER_DATE', 'EXAM_TYPE',
#        'FIRST_MAMMO_IND', 'LAST_ACTIVITY_DATE', 'INTERNAL_EXAM_ID',
#        'PATIENT_ID', 'study'],
#       dtype='object')

# %%
extract_cols = ['PATIENT_STUDY_ID', 'ACCESSION_NUMBER', 'EXAM_TYPE', 'study']

# %%
cancer_cohort_copy = cancer_cohort.copy()
pdi_copy = pdi[extract_cols].copy()

# %%
cancer_cols = cancer_cohort_copy.columns
pdi_cols = pdi_copy.columns

# %%
merge = pd.merge(cancer_cohort_copy, pdi_copy, how="left", on=['PATIENT_STUDY_ID', 'ACCESSION_NUMBER'])

# %%
merge[merge["PATIENT_STUDY_ID"]==4330344296]
# Out:
#      PATIENT_STUDY_ID  ACCESSION_NUMBER                   COMPOSITION_NAME  \
# 108        4330344296        71644307.0  Heterogeneously dense (51% - 75%)
# 109        4330344296        76610889.0  Heterogeneously dense (51% - 75%)
# 110        4330344296        76610889.0  Heterogeneously dense (51% - 75%)
# 111        4330344296        76695188.0  Heterogeneously dense (51% - 75%)
# 112        4330344296        62861703.0  Heterogeneously dense (51% - 75%)
# 113        4330344296        67469599.0  Heterogeneously dense (51% - 75%)
# 114        4330344296        67469599.0  Heterogeneously dense (51% - 75%)
# 115        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 116        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 117        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 118        4330344296       453737129.0  Heterogeneously dense (51% - 75%)
#
#     FINDING_LOCATION                                   FINDING_CATEGORY  \
# 108              NaN                                 2 - Benign finding
# 109              NaN             0 - Need additional imaging evaluation
# 110              NaN                                       1 - Negative
# 111              NaN                                 2 - Benign finding
# 112              NaN                                 2 - Benign finding
# 113              NaN             0 - Need additional imaging evaluation
# 114              NaN                                       1 - Negative
# 115              NaN  4A - Suspicious abnormality - biopsy should be...
# 116              NaN  4A - Suspicious abnormality - biopsy should be...
# 117              NaN  4A - Suspicious abnormality - biopsy should be...
# 118              NaN                                 2 - Benign finding
#
#                        FINDING_REC EXAM_COMPLETED_DATE  duplicate_count  \
# 108    N-Normal interval follow-up          2017-07-31              2.0
# 109       P-Additional projections          2018-10-31              1.0
# 110    N-Normal interval follow-up          2018-10-31              1.0
# 111    N-Normal interval follow-up          2018-11-08              1.0
# 112    N-Normal interval follow-up          2019-12-20              2.0
# 113       P-Additional projections          2020-12-31              1.0
# 114    N-Normal interval follow-up          2020-12-31              1.0
# 115  B-Biopsy should be considered          2021-01-25              2.0
# 116  B-Biopsy should be considered          2021-01-25              2.0
# 117  B-Biopsy should be considered          2021-01-25              2.0
# 118    N-Normal interval follow-up          2022-02-10              1.0
#
#       StudyDate StudyTime study_x  image_available  dbt_available     BX_ID  \
# 108  2017-07-31  02:23:29  SCREEN              1.0            NaN       NaN
# 109  2018-10-31  16:35:19  SCREEN              1.0            NaN       NaN
# 110  2018-10-31  16:35:19  SCREEN              1.0            NaN       NaN
# 111  2018-11-08  15:23:00    DIAG              1.0            NaN       NaN
# 112  2019-12-20  02:44:43  SCREEN              1.0            NaN       NaN
# 113  2020-12-31  08:39:44  SCREEN              1.0            NaN       NaN
# 114  2020-12-31  08:39:44  SCREEN              1.0            NaN       NaN
# 115         NaN       NaN     NaN              NaN            NaN  470168.0
# 116         NaN       NaN     NaN              NaN            NaN  470167.0
# 117         NaN       NaN     NaN              NaN            NaN  478775.0
# 118         NaN       NaN     NaN              NaN            NaN       NaN
#
#     PATHOLOGY_DATE LESION_CLASS SIDE    EXAM_TYPE study_y
# 108            NaT          NaN  NaN  Mammography  SCREEN
# 109            NaT          NaN  NaN  Mammography  SCREEN
# 110            NaT          NaN  NaN  Mammography  SCREEN
# 111            NaT          NaN  NaN  Mammography    DIAG
# 112            NaT          NaN  NaN  Mammography  SCREEN
# 113            NaT          NaN  NaN  Mammography  SCREEN
# 114            NaT          NaN  NaN  Mammography  SCREEN
# 115     2021-02-10    Malignant    R  Mammography    DIAG
# 116     2021-02-10       Benign    R  Mammography    DIAG
# 117     2021-03-05    Malignant    R  Mammography    DIAG
# 118            NaT          NaN  NaN  Mammography    DIAG

# %%
# Create the final 'study' column by prioritizing cancer cohort (study info from DICOM), then patient_data_ie
merge['study'] = merge['study_x'].combine_first(merge['study_y'])
final = merge.drop(columns=['study_x', 'study_y'])

# %%
output_file = os.path.join("../Data/", study, 'cancer_cohort' + ".xlsx")
final.to_excel(output_file, index=False)

# %% [markdown]
# # II. Extract <span style="color:blue;">**MO cancer**</span> record

# %% [markdown]
# ## <span style="color:#FF6347;">**READ**</span> file (cancer_cohort)

# %%
output_file = os.path.join("../Data/", "Cancer", 'cancer_cohort' + ".xlsx")
cancer_cohort = pd.read_excel(output_file)

# %%
PIDs = cancer_cohort["PATIENT_STUDY_ID"].unique()

# %%
len(PIDs)
# Out:
# 1956

# %% [markdown]
# ## 1. Locate <span style="color:blue;">**cancer**</span> index year, "index status" = <span style="color:#8A2BE2;">**INDEX**</span>

# %% [markdown]
# #### See [inclusion criteria][ic] to for filtering
#
# [ic]: https://pitt-my.sharepoint.com/:w:/r/personal/trl117_pitt_edu/_layouts/15/doc.aspx?sourcedoc=%7B9c403413-a771-4830-98ab-15171872c4dd%7D&action=edit

# %% [markdown]
# #### Find the earliest "Malignant" record in pathology and marked the pathology date as <span style="color:#8A2BE2;">**INDEX**</span>, then drop all after

# %%
# Create a column called "index status"
cohort = cancer_cohort.copy()
cohort['index status'] = None

# %%
# 1. Sort to find the earliest Malignant PATHOLOGY_DATE
cohort_sorted_pathology = cohort.sort_values(
    ['PATIENT_STUDY_ID', 'PATHOLOGY_DATE']
)

# Filter for only 'Malignant' records by dropping duplicates
first_malignant_indices = cohort_sorted_pathology[
    cohort_sorted_pathology['LESION_CLASS'] == 'Malignant'
].drop_duplicates(
    subset=['PATIENT_STUDY_ID'],
    keep='first'
).index.tolist()

# 2. Mark the corresponding "index status" as "INDEX"
cohort.loc[first_malignant_indices, 'index status'] = 'INDEX'

# Create a clean target DataFrame for the next merge step
target_df = cohort.loc[first_malignant_indices].copy().rename(
    columns={'PATHOLOGY_DATE': 'target pathology date'}
)

# %% [markdown]
# #### Find the SCREEN/DIAGNOSIS exam that occurred within 1 year of the <span style="color:#8A2BE2;">**INDEX**</span> Pathology Date, marked as <span style="color:#8A2BE2;">**INDEX**</span>

# %%
# 3. Locate Exams within One Year of Index Pathology Date

tar_lookup = target_df.set_index('PATIENT_STUDY_ID')['target pathology date']
cohort['target pathology date'] = cohort['PATIENT_STUDY_ID'].map(tar_lookup)

# Calculate the time difference (Pathology Date - Exam Date)
# Negative difference means the exam occurred AFTER the pathology (we want to exclude these later)
cohort['path to exam diff'] = cohort['target pathology date'] - cohort['EXAM_COMPLETED_DATE']

# Create a boolean mask for exams within 1 year (365 days) BEFORE or ON the pathology date
one_year = pd.Timedelta(days=365)
# Condition 1: Exam occurred before or on the pathology date (Pathology - Exam >= 0)
mask_preceding = cohort['path to exam diff'] >= pd.Timedelta(days=0)
# Condition 2: Exam occurred within 1 year before the pathology date (Pathology - Exam <= 365 days)
mask_within_year = cohort['path to exam diff'] <= one_year
# Combined mask: Preceding AND within 1 year
mask_index_cohort = mask_preceding & mask_within_year

# %%
# Mark all rows matching the criteria as "index" (overwriting 'Other', retaining the original 'index' marks)
cohort.loc[mask_index_cohort, 'index status'] = 'INDEX'

print(f"✅ Step 3 Complete. Marked {cohort[cohort['index status'] == 'INDEX'].shape[0]} rows as 'INDEX'.")
# Out:
# ✅ Step 3 Complete. Marked 7040 rows as 'INDEX'.

# %%
cohort['index status'].unique()
# Out:
# array(['INDEX', None], dtype=object)

# %%
cohort[cohort["PATIENT_STUDY_ID"]==4330344296]
# Out:
#      PATIENT_STUDY_ID  ACCESSION_NUMBER                   COMPOSITION_NAME  \
# 108        4330344296        71644307.0  Heterogeneously dense (51% - 75%)
# 109        4330344296        76610889.0  Heterogeneously dense (51% - 75%)
# 110        4330344296        76610889.0  Heterogeneously dense (51% - 75%)
# 111        4330344296        76695188.0  Heterogeneously dense (51% - 75%)
# 112        4330344296        62861703.0  Heterogeneously dense (51% - 75%)
# 113        4330344296        67469599.0  Heterogeneously dense (51% - 75%)
# 114        4330344296        67469599.0  Heterogeneously dense (51% - 75%)
# 115        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 116        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 117        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 118        4330344296       453737129.0  Heterogeneously dense (51% - 75%)
#
#     FINDING_LOCATION                                   FINDING_CATEGORY  \
# 108              NaN                                 2 - Benign finding
# 109              NaN             0 - Need additional imaging evaluation
# 110              NaN                                       1 - Negative
# 111              NaN                                 2 - Benign finding
# 112              NaN                                 2 - Benign finding
# 113              NaN             0 - Need additional imaging evaluation
# 114              NaN                                       1 - Negative
# 115              NaN  4A - Suspicious abnormality - biopsy should be...
# 116              NaN  4A - Suspicious abnormality - biopsy should be...
# 117              NaN  4A - Suspicious abnormality - biopsy should be...
# 118              NaN                                 2 - Benign finding
#
#                        FINDING_REC EXAM_COMPLETED_DATE  duplicate_count  \
# 108    N-Normal interval follow-up          2017-07-31              2.0
# 109       P-Additional projections          2018-10-31              1.0
# 110    N-Normal interval follow-up          2018-10-31              1.0
# 111    N-Normal interval follow-up          2018-11-08              1.0
# 112    N-Normal interval follow-up          2019-12-20              2.0
# 113       P-Additional projections          2020-12-31              1.0
# 114    N-Normal interval follow-up          2020-12-31              1.0
# 115  B-Biopsy should be considered          2021-01-25              2.0
# 116  B-Biopsy should be considered          2021-01-25              2.0
# 117  B-Biopsy should be considered          2021-01-25              2.0
# 118    N-Normal interval follow-up          2022-02-10              1.0
#
#       StudyDate StudyTime  image_available  dbt_available     BX_ID  \
# 108  2017-07-31  02:23:29              1.0            NaN       NaN
# 109  2018-10-31  16:35:19              1.0            NaN       NaN
# 110  2018-10-31  16:35:19              1.0            NaN       NaN
# 111  2018-11-08  15:23:00              1.0            NaN       NaN
# 112  2019-12-20  02:44:43              1.0            NaN       NaN
# 113  2020-12-31  08:39:44              1.0            NaN       NaN
# 114  2020-12-31  08:39:44              1.0            NaN       NaN
# 115         NaN       NaN              NaN            NaN  470168.0
# 116         NaN       NaN              NaN            NaN  470167.0
# 117         NaN       NaN              NaN            NaN  478775.0
# 118         NaN       NaN              NaN            NaN       NaN
#
#     PATHOLOGY_DATE LESION_CLASS SIDE    EXAM_TYPE   study index status  \
# 108            NaT          NaN  NaN  Mammography  SCREEN         None
# 109            NaT          NaN  NaN  Mammography  SCREEN         None
# 110            NaT          NaN  NaN  Mammography  SCREEN         None
# 111            NaT          NaN  NaN  Mammography    DIAG         None
# 112            NaT          NaN  NaN  Mammography  SCREEN         None
# 113            NaT          NaN  NaN  Mammography  SCREEN        INDEX
# 114            NaT          NaN  NaN  Mammography  SCREEN        INDEX
# 115     2021-02-10    Malignant    R  Mammography    DIAG        INDEX
# 116     2021-02-10       Benign    R  Mammography    DIAG        INDEX
# 117     2021-03-05    Malignant    R  Mammography    DIAG        INDEX
# 118            NaT          NaN  NaN  Mammography    DIAG         None
#
#     target pathology date path to exam diff
# 108            2021-02-10         1290 days
# 109            2021-02-10          833 days
# 110            2021-02-10          833 days
# 111            2021-02-10          825 days
# 112            2021-02-10          418 days
# 113            2021-02-10           41 days
# 114            2021-02-10           41 days
# 115            2021-02-10           16 days
# 116            2021-02-10           16 days
# 117            2021-02-10           16 days
# 118            2021-02-10         -365 days

# %% [markdown]
# ## 2. Locate <span style="color:blue;">**MO cancer**</span> year, "index status" = <span style="color:#00BFFF;">**INDEX-1**</span>

# %% [markdown]
# #### See [inclusion criteria][ic] to for filtering
#
# [ic]: https://pitt-my.sharepoint.com/:w:/r/personal/trl117_pitt_edu/_layouts/15/doc.aspx?sourcedoc=%7B9c403413-a771-4830-98ab-15171872c4dd%7D&action=edit

# %% [markdown]
# ### 2a. Find the earliest <span style="color:#8A2BE2;">**INDEX**</span> exam date

# %% [markdown]
# #### Find the earliest EXAM_COMPLETED_DATE marked as <span style="color:#8A2BE2;">**"INDEX"**</span>

# %%
# 1. Isolate the current "INDEX" records
index_records = cohort[cohort['index status'] == 'INDEX'].copy()

# 2. Find the earliest EXAM_COMPLETED_DATE for the current "INDEX" cohort
earliest_index_exam = index_records.sort_values(
    ['PATIENT_STUDY_ID', 'EXAM_COMPLETED_DATE']
).drop_duplicates(
    subset=['PATIENT_STUDY_ID'],
    keep='first'
)

# Rename the earliest exam date for clarity in the merge
earliest_index_exam.rename(
    columns={'EXAM_COMPLETED_DATE': 'target index date'},
    inplace=True
)

# %%
earliest_index_exam
# Out:
#        PATIENT_STUDY_ID  ACCESSION_NUMBER                   COMPOSITION_NAME  \
# 0            4330018595        63027507.0  Heterogeneously dense (51% - 75%)
# 13           4330066079        61259016.0  Heterogeneously dense (51% - 75%)
# 28           4330170072        79434020.0  Heterogeneously dense (51% - 75%)
# 40           4330303540        73123621.0  Heterogeneously dense (51% - 75%)
# 48           4330325599        75132824.0  Heterogeneously dense (51% - 75%)
# ...                 ...               ...                                ...
# 24795        4339508544        71405606.0  Heterogeneously dense (51% - 75%)
# 24816        4339577807               NaN                                NaN
# 24819        4339582412        78690585.0  Heterogeneously dense (51% - 75%)
# 24841        4339604670        68584905.0  Heterogeneously dense (51% - 75%)
# 24853        4339617268        68100499.0  Heterogeneously dense (51% - 75%)
#
#       FINDING_LOCATION                                   FINDING_CATEGORY  \
# 0                  NaN             0 - Need additional imaging evaluation
# 13                 NaN                                 2 - Benign finding
# 28                 NaN  99 - Post procedure mammograms for marker plac...
# 40                 NaN             0 - Need additional imaging evaluation
# 48                 NaN                                 2 - Benign finding
# ...                ...                                                ...
# 24795              NaN             0 - Need additional imaging evaluation
# 24816              NaN                                                NaN
# 24819              NaN     3 - Probably benign - short interval follow-up
# 24841              NaN             0 - Need additional imaging evaluation
# 24853              NaN             0 - Need additional imaging evaluation
#
#                                             FINDING_REC target index date  \
# 0                              P-Additional projections        2019-07-26
# 13                          N-Normal interval follow-up        2020-01-14
# 28     X-Follow-up post biopsy as directed by clinician        2017-10-27
# 40                             P-Additional projections        2016-12-21
# 48                          N-Normal interval follow-up        2016-04-20
# ...                                                 ...               ...
# 24795                          P-Additional projections        2017-05-03
# 24816                                               NaN               NaT
# 24819       F-Follow-up at short interval (1-11 months)        2018-04-25
# 24841                          P-Additional projections        2020-11-27
# 24853                          P-Additional projections        2020-11-25
#
#        duplicate_count   StudyDate StudyTime  image_available  dbt_available  \
# 0                  2.0         NaN       NaN              NaN            NaN
# 13                 2.0  2020-01-14  18:25:58              1.0            1.0
# 28                 1.0         NaN       NaN              NaN            NaN
# 40                 2.0         NaN       NaN              NaN            NaN
# 48                 1.0  2016-04-20  02:32:42              1.0            1.0
# ...                ...         ...       ...              ...            ...
# 24795              2.0         NaN       NaN              NaN            NaN
# 24816              NaN         NaN       NaN              NaN            NaN
# 24819              2.0         NaN       NaN              NaN            NaN
# 24841              1.0         NaN       NaN              NaN            NaN
# 24853              2.0         NaN       NaN              NaN            NaN
#
#           BX_ID PATHOLOGY_DATE LESION_CLASS SIDE            EXAM_TYPE   study  \
# 0           NaN            NaT          NaN  NaN          Mammography  SCREEN
# 13          NaN            NaT          NaN  NaN          Mammography    DIAG
# 28     436484.0     2017-11-16    Malignant    L                Other     NaN
# 40          NaN            NaT          NaN  NaN  Digital Mammography  SCREEN
# 48          NaN            NaT          NaN  NaN          Mammography    DIAG
# ...         ...            ...          ...  ...                  ...     ...
# 24795       NaN            NaT          NaN  NaN  Digital Mammography  SCREEN
# 24816  489989.0     2018-10-11    Malignant    L                  NaN     NaN
# 24819       NaN            NaT          NaN  NaN                Other     NaN
# 24841       NaN            NaT          NaN  NaN          Mammography  SCREEN
# 24853       NaN            NaT          NaN  NaN          Mammography  SCREEN
#
#       index status target pathology date path to exam diff
# 0            INDEX            2020-06-05          315 days
# 13           INDEX            2020-06-17          155 days
# 28           INDEX            2017-11-16           20 days
# 40           INDEX            2017-01-27           37 days
# 48           INDEX            2016-04-20            0 days
# ...            ...                   ...               ...
# 24795        INDEX            2018-01-23          265 days
# 24816        INDEX            2018-10-11               NaT
# 24819        INDEX            2018-05-08           13 days
# 24841        INDEX            2020-12-22           25 days
# 24853        INDEX            2021-01-12           48 days
#
# [1956 rows x 21 columns]

# %% [markdown]
# ### 2b. Find the preceding exam, <span style="color:blue;">**MO cancer**</span> year, <span style="color:#00BFFF;">**INDEX-1**</span>

# %% [markdown]
# #### Find the preceding exam that occurred at least 9 months before the earliest <span style="color:#8A2BE2;">**"INDEX"**</span> exam date but not before 18 months

# %%
# 3. Locate closest preceding exam, time difference between closest preceding exam date and Index Exam Date should fall in the range 9 months ~ 1.5 year

tar_lookup = earliest_index_exam.set_index('PATIENT_STUDY_ID')['target index date']
cohort['target index date'] = cohort['PATIENT_STUDY_ID'].map(tar_lookup)

# Calculate the time difference (INDEX Exam Date - Exam Date)
# Negative difference means the exam occurred AFTER the index (we want to exclude these later)
cohort['index to exam diff'] = cohort['target index date'] - cohort['EXAM_COMPLETED_DATE']

# %%
# Create a boolean mask for exams more than 9 months and less than 18 months BEFORE the index date
nine_month = pd.Timedelta(days=274)
eighteen_month = pd.Timedelta(days=548)
# Condition 1: Exam occurred before the INDEX exam date (INDEX Exam - Exam > 0)
mask_preceding = cohort['index to exam diff'] > pd.Timedelta(days=0)
# Condition 2: Exam occurred within or on 18 months before INDEX exam date (INDEX Exam - Exam <= 18 months)
mask_within_18_month = cohort['index to exam diff'] <= eighteen_month
# Condition 3: Exam occurred more than or on 9 months before INDEX exam date (INDEX Exam - Exam >= 9 months)
mask_more_9_month = cohort['index to exam diff'] >= nine_month
# Combined mask: Preceding AND within 18 months AND more than 9 months
mask_index_1_cohort = mask_preceding & mask_within_18_month & mask_more_9_month

# %%
# Mark all rows matching the criteria as "index" (overwriting 'Other', retaining the original 'index' marks)
cohort.loc[mask_index_1_cohort, 'index status'] = 'INDEX-1'

print(f"✅ Step 4 Complete. Marked {cohort[cohort['index status'] == 'INDEX-1'].shape[0]} rows as 'INDEX-1'.")
# Out:
# ✅ Step 4 Complete. Marked 1198 rows as 'INDEX-1'.

# %%
cohort["index status"].unique()
# Out:
# array(['INDEX', None, 'INDEX-1'], dtype=object)

# %%
cohort_sort = cohort.sort_values(['PATIENT_STUDY_ID', 'EXAM_COMPLETED_DATE', 'ACCESSION_NUMBER']).reset_index(drop=True)

# %%
cohort_sort[cohort_sort["PATIENT_STUDY_ID"]==4330344296]
# Out:
#      PATIENT_STUDY_ID  ACCESSION_NUMBER                   COMPOSITION_NAME  \
# 108        4330344296        71644307.0  Heterogeneously dense (51% - 75%)
# 109        4330344296        76610889.0  Heterogeneously dense (51% - 75%)
# 110        4330344296        76610889.0  Heterogeneously dense (51% - 75%)
# 111        4330344296        76695188.0  Heterogeneously dense (51% - 75%)
# 112        4330344296        62861703.0  Heterogeneously dense (51% - 75%)
# 113        4330344296        67469599.0  Heterogeneously dense (51% - 75%)
# 114        4330344296        67469599.0  Heterogeneously dense (51% - 75%)
# 115        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 116        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 117        4330344296        67156697.0  Heterogeneously dense (51% - 75%)
# 118        4330344296       453737129.0  Heterogeneously dense (51% - 75%)
#
#     FINDING_LOCATION                                   FINDING_CATEGORY  \
# 108              NaN                                 2 - Benign finding
# 109              NaN             0 - Need additional imaging evaluation
# 110              NaN                                       1 - Negative
# 111              NaN                                 2 - Benign finding
# 112              NaN                                 2 - Benign finding
# 113              NaN             0 - Need additional imaging evaluation
# 114              NaN                                       1 - Negative
# 115              NaN  4A - Suspicious abnormality - biopsy should be...
# 116              NaN  4A - Suspicious abnormality - biopsy should be...
# 117              NaN  4A - Suspicious abnormality - biopsy should be...
# 118              NaN                                 2 - Benign finding
#
#                        FINDING_REC EXAM_COMPLETED_DATE  duplicate_count  \
# 108    N-Normal interval follow-up          2017-07-31              2.0
# 109       P-Additional projections          2018-10-31              1.0
# 110    N-Normal interval follow-up          2018-10-31              1.0
# 111    N-Normal interval follow-up          2018-11-08              1.0
# 112    N-Normal interval follow-up          2019-12-20              2.0
# 113       P-Additional projections          2020-12-31              1.0
# 114    N-Normal interval follow-up          2020-12-31              1.0
# 115  B-Biopsy should be considered          2021-01-25              2.0
# 116  B-Biopsy should be considered          2021-01-25              2.0
# 117  B-Biopsy should be considered          2021-01-25              2.0
# 118    N-Normal interval follow-up          2022-02-10              1.0
#
#       StudyDate StudyTime  image_available  dbt_available     BX_ID  \
# 108  2017-07-31  02:23:29              1.0            NaN       NaN
# 109  2018-10-31  16:35:19              1.0            NaN       NaN
# 110  2018-10-31  16:35:19              1.0            NaN       NaN
# 111  2018-11-08  15:23:00              1.0            NaN       NaN
# 112  2019-12-20  02:44:43              1.0            NaN       NaN
# 113  2020-12-31  08:39:44              1.0            NaN       NaN
# 114  2020-12-31  08:39:44              1.0            NaN       NaN
# 115         NaN       NaN              NaN            NaN  470168.0
# 116         NaN       NaN              NaN            NaN  470167.0
# 117         NaN       NaN              NaN            NaN  478775.0
# 118         NaN       NaN              NaN            NaN       NaN
#
#     PATHOLOGY_DATE LESION_CLASS SIDE    EXAM_TYPE   study index status  \
# 108            NaT          NaN  NaN  Mammography  SCREEN         None
# 109            NaT          NaN  NaN  Mammography  SCREEN         None
# 110            NaT          NaN  NaN  Mammography  SCREEN         None
# 111            NaT          NaN  NaN  Mammography    DIAG         None
# 112            NaT          NaN  NaN  Mammography  SCREEN      INDEX-1
# 113            NaT          NaN  NaN  Mammography  SCREEN        INDEX
# 114            NaT          NaN  NaN  Mammography  SCREEN        INDEX
# 115     2021-02-10    Malignant    R  Mammography    DIAG        INDEX
# 116     2021-02-10       Benign    R  Mammography    DIAG        INDEX
# 117     2021-03-05    Malignant    R  Mammography    DIAG        INDEX
# 118            NaT          NaN  NaN  Mammography    DIAG         None
#
#     target pathology date path to exam diff target index date  \
# 108            2021-02-10         1290 days        2020-12-31
# 109            2021-02-10          833 days        2020-12-31
# 110            2021-02-10          833 days        2020-12-31
# 111            2021-02-10          825 days        2020-12-31
# 112            2021-02-10          418 days        2020-12-31
# 113            2021-02-10           41 days        2020-12-31
# 114            2021-02-10           41 days        2020-12-31
# 115            2021-02-10           16 days        2020-12-31
# 116            2021-02-10           16 days        2020-12-31
# 117            2021-02-10           16 days        2020-12-31
# 118            2021-02-10         -365 days        2020-12-31
#
#     index to exam diff
# 108          1249 days
# 109           792 days
# 110           792 days
# 111           784 days
# 112           377 days
# 113             0 days
# 114             0 days
# 115           -25 days
# 116           -25 days
# 117           -25 days
# 118          -406 days

# %%
output_file = os.path.join("../Data/", study, 'cancer_cohort_w_index' + ".xlsx")
cohort_sort.to_excel(output_file, index=False)

# %% [markdown]
# ## 3. Extract <span style="color:blue;">**MO cancer**</span> cohort only

# %% [markdown]
# ### <span style="color:#FF6347;">**READ**</span> file (cancer_cohort_w_index)

# %%
output_file = os.path.join("../Data/", study, 'cancer_cohort_w_index' + ".xlsx")
cohort = pd.read_excel(output_file)

# %%
PIDs = cohort["PATIENT_STUDY_ID"].unique()

# %% [markdown]
# ### **Criteria**:
# #### 1. At <span style="color:#8A2BE2;">**INDEX**</span>, "LESION_CLASS" = "Malignant"
# ##### no need to check as all patients in cancer_cohort already meet this criteria
# #### 2. At <span style="color:#00BFFF;">**INDEX-1**</span>, "image_available" = 1
# #### 3. At <span style="color:#00BFFF;">**INDEX-1**</span>, "FINDING_CATEGORY" = "1 - Negative", "2 - Benign finding"
# #### 4. At <span style="color:#00BFFF;">**INDEX-1**</span>, "study" = "SCREEN"

# %%
idx_index_1 = cohort["index status"]=="INDEX-1"
idx_img = cohort["image_available"]==1
idx_dbt = cohort["dbt_available"]==1
idx_screen = cohort["study"]=="SCREEN"
idx_birads_0 = cohort["FINDING_CATEGORY"]=="0 - Need additional imaging evaluation"
idx_birads_1 = cohort["FINDING_CATEGORY"]=="1 - Negative"
idx_birads_2 = cohort["FINDING_CATEGORY"]=="2 - Benign finding"

# %% [markdown]
# #### [N=384] Meet **criteria #2**

# %%
pids_criteria_2 = cohort[idx_index_1 & idx_img]["PATIENT_STUDY_ID"].unique()

# %%
len(pids_criteria_2)
# Out:
# 384

# %% [markdown]
# #### [N=378] Meet **criteria #2 <span style="color:red">**AND**</span> #3**

# %%
pids_criteria_2_3 = cohort[(idx_index_1 & idx_img & idx_birads_1) | (idx_index_1 & idx_img & idx_birads_2)]["PATIENT_STUDY_ID"].unique()

# %%
len(pids_criteria_2_3)
# Out:
# 378

# %% [markdown]
# #### [N=31] Meet **criteria #2** <span style="color:red">**AND**</span> At <span style="color:#00BFFF;">**INDEX-1**</span>, "FINDING_CATEGORY" = "0 - Need additional imaging evaluation"

# %%
pids_criteria_2_birads_0 = cohort[idx_index_1 & idx_img & idx_birads_0]["PATIENT_STUDY_ID"].unique()

# %%
len(pids_criteria_2_birads_0)
# Out:
# 31

# %%
len(set(pids_criteria_2_3.tolist()) & set(pids_criteria_2_birads_0.tolist()))
# Out:
# 31

# %% [markdown]
# ##### <span style="color:#FF6347;">**SAVE**</span>

# %%
cohort_filtered = cohort[cohort['PATIENT_STUDY_ID'].isin(pids_criteria_2_birads_0)].reset_index(drop=True)
cohort_filtered_sort = cohort_filtered.sort_values(['PATIENT_STUDY_ID', 'EXAM_COMPLETED_DATE', 'ACCESSION_NUMBER']).reset_index(drop=True)
output_file = os.path.join("../Data/", study, 'mo_cancer_cohort_N_31' + ".xlsx")
cohort_filtered.to_excel(output_file, index=False)

# %% [markdown]
# #### [N=219] Meet **criteria #2 <span style="color:red">**AND**</span> #3 <span style="color:red">**AND**</span> #4**  → Remove any BIRADS=0 at <span style="color:#00BFFF;">**INDEX-1**</span> → <span style="color:#FF6347;">**SAVE AS**</span> **mo_cancer_cohort**

# %% [markdown]
# ##### Meet **criteria #2 <span style="color:red">**AND**</span> #3 <span style="color:red">**AND**</span> #4**

# %%
pids_criteria_all = cohort[(idx_screen & idx_index_1 & idx_img & idx_birads_1) | (idx_screen & idx_index_1 & idx_img & idx_birads_2)]["PATIENT_STUDY_ID"].unique()

# %%
len(pids_criteria_all)
# Out:
# 251

# %% [markdown]
# ##### Remove any BIRADS=0 at <span style="color:#00BFFF;">**INDEX-1**</span>

# %%
pids_birads_0 = cohort[idx_index_1 & idx_birads_0]["PATIENT_STUDY_ID"].unique()

# %%
set_pids_common = set(pids_criteria_all) & set(pids_birads_0)

# %%
pids_mo = list(set(pids_criteria_all).difference(set_pids_common))

# %%
len(pids_mo)
# Out:
# 219

# %% [markdown]
# #### [N=20] Meet **criteria #2 <span style="color:red">**AND**</span> #3 <span style="color:red">**AND**</span> #4** <span style="color:red">**AND**</span> **DBT available** → Remove any BIRADS=0 at <span style="color:#00BFFF;">**INDEX-1**</span>

# %% [markdown]
# ##### Meet **criteria #2 <span style="color:red">**AND**</span> #3 <span style="color:red">**AND**</span> #4**<span style="color:red">**AND**</span> DBT available

# %%
pids_criteria_all_dbt = cohort[(idx_dbt & idx_screen & idx_index_1 & idx_img & idx_birads_1) | (idx_dbt & idx_screen & idx_index_1 & idx_img & idx_birads_2)]["PATIENT_STUDY_ID"].unique()

# %%
len(pids_criteria_all_dbt)
# Out:
# 22

# %% [markdown]
# ##### Remove any BIRADS=0 at <span style="color:#00BFFF;">**INDEX-1**</span>

# %%
set_pids_common = set(pids_criteria_all_dbt) & set(pids_birads_0)

# %%
pids_mo_dbt = list(set(pids_criteria_all_dbt).difference(set_pids_common))

# %%
len(pids_mo_dbt)
# Out:
# 20

# %% [markdown]
# ##### <span style="color:#FF6347;">**SAVE**</span>

# %%
cohort_filtered = cohort[cohort['PATIENT_STUDY_ID'].isin(pids_mo_dbt)].reset_index(drop=True)
cohort_filtered_sort = cohort_filtered.sort_values(['PATIENT_STUDY_ID', 'EXAM_COMPLETED_DATE', 'ACCESSION_NUMBER']).reset_index(drop=True)
output_file = os.path.join("../Data/", study, 'mo_cancer_cohort_dbt' + ".xlsx")
cohort_filtered.to_excel(output_file, index=False)

# %% [markdown]
# #### <span style="color:#FF6347;">**SAVE**</span> **mo_cancer_cohort**

# %%
cohort_filtered = cohort[cohort['PATIENT_STUDY_ID'].isin(pids_mo)].reset_index(drop=True)

# %%
cohort_filtered[cohort_filtered["PATIENT_STUDY_ID"]==4337724790]
# Out:
#       PATIENT_STUDY_ID  ACCESSION_NUMBER                   COMPOSITION_NAME  \
# 2821        4337724790        63408900.0  Heterogeneously dense (51% - 75%)
# 2822        4337724790        60961176.0  Heterogeneously dense (51% - 75%)
# 2823        4337724790       455418188.0  Heterogeneously dense (51% - 75%)
# 2824        4337724790       455418188.0  Heterogeneously dense (51% - 75%)
# 2825        4337724790       455075546.0  Heterogeneously dense (51% - 75%)
# 2826        4337724790       451418694.0  Heterogeneously dense (51% - 75%)
# 2827        4337724790       451418694.0  Heterogeneously dense (51% - 75%)
# 2828        4337724790       451048623.0  Heterogeneously dense (51% - 75%)
# 2829        4337724790       450750121.0  Heterogeneously dense (51% - 75%)
#
#      FINDING_LOCATION                                   FINDING_CATEGORY  \
# 2821              NaN                                       1 - Negative
# 2822              NaN                                 2 - Benign finding
# 2823              NaN             0 - Need additional imaging evaluation
# 2824              NaN                                       1 - Negative
# 2825              NaN                                       1 - Negative
# 2826              NaN             0 - Need additional imaging evaluation
# 2827              NaN                                       1 - Negative
# 2828              NaN  4B - Suspicious abnormality - biopsy should be...
# 2829              NaN                                       1 - Negative
#
#                         FINDING_REC EXAM_COMPLETED_DATE  duplicate_count  \
# 2821    N-Normal interval follow-up          2019-06-01              2.0
# 2822    N-Normal interval follow-up          2020-06-02              2.0
# 2823       P-Additional projections          2021-06-19              1.0
# 2824    N-Normal interval follow-up          2021-06-19              1.0
# 2825    N-Normal interval follow-up          2021-08-03              1.0
# 2826       P-Additional projections          2022-06-30              1.0
# 2827    N-Normal interval follow-up          2022-06-30              1.0
# 2828  B-Biopsy should be considered          2022-07-13              1.0
# 2829    N-Normal interval follow-up          2022-10-25              1.0
#
#        StudyDate StudyTime  image_available  dbt_available     BX_ID  \
# 2821  2019-06-01  15:09:20              1.0            NaN       NaN
# 2822  2020-06-02  09:37:45              1.0            NaN       NaN
# 2823         NaN       NaN              NaN            NaN       NaN
# 2824         NaN       NaN              NaN            NaN       NaN
# 2825         NaN       NaN              NaN            NaN       NaN
# 2826         NaN       NaN              NaN            NaN       NaN
# 2827         NaN       NaN              NaN            NaN       NaN
# 2828  2022-07-13  01:55:07              1.0            NaN  352533.0
# 2829         NaN       NaN              NaN            NaN  351055.0
#
#      PATHOLOGY_DATE LESION_CLASS SIDE                 EXAM_TYPE   study  \
# 2821            NaT          NaN  NaN               Mammography  SCREEN
# 2822            NaT          NaN  NaN               Mammography  SCREEN
# 2823            NaT          NaN  NaN               Mammography  SCREEN
# 2824            NaT          NaN  NaN               Mammography  SCREEN
# 2825            NaT          NaN  NaN               Mammography    DIAG
# 2826            NaT          NaN  NaN               Mammography  SCREEN
# 2827            NaT          NaN  NaN               Mammography  SCREEN
# 2828     2022-07-21    Malignant    L               Mammography    DIAG
# 2829     2022-10-25    Malignant    L  Interventional procedure     NaN
#
#      index status target pathology date  path to exam diff target index date  \
# 2821          NaN            2022-07-21             1146.0        2021-08-03
# 2822      INDEX-1            2022-07-21              779.0        2021-08-03
# 2823          NaN            2022-07-21              397.0        2021-08-03
# 2824          NaN            2022-07-21              397.0        2021-08-03
# 2825        INDEX            2022-07-21              352.0        2021-08-03
# 2826        INDEX            2022-07-21               21.0        2021-08-03
# 2827        INDEX            2022-07-21               21.0        2021-08-03
# 2828        INDEX            2022-07-21                8.0        2021-08-03
# 2829          NaN            2022-07-21              -96.0        2021-08-03
#
#       index to exam diff
# 2821               794.0
# 2822               427.0
# 2823                45.0
# 2824                45.0
# 2825                 0.0
# 2826              -331.0
# 2827              -331.0
# 2828              -344.0
# 2829              -448.0

# %%
cohort_filtered_sort = cohort_filtered.sort_values(['PATIENT_STUDY_ID', 'EXAM_COMPLETED_DATE', 'ACCESSION_NUMBER']).reset_index(drop=True)

# %%
output_file = os.path.join("../Data/", study, 'mo_cancer_cohort' + ".xlsx")
cohort_filtered.to_excel(output_file, index=False)

# %% [markdown]
# ## <span style="color:#FF6347;">**READ**</span> file

# %%
output_file = os.path.join("../Data/", study, 'mo_cancer_cohort' + ".xlsx")
cohort = pd.read_excel(output_file)

# %%
PIDs = cohort["PATIENT_STUDY_ID"].unique()

# %%
len(PIDs)
# Out:
# 219

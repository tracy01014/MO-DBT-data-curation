# %%
import pandas as pd
import os
import numpy as np
import re

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data curation

# %% [markdown]
# ##### 1. Combine dicomtocsv_series.csv and dicomtocsv_study.csv
# ##### 2. Group by PatientID

# %%
def merge_and_extract(file_path, file_series, file_study, output_file, extract_cols):
    """
    Merges two files into a single file based on shared columns, then extract desired columns
    """
    
    df_dicom_series = pd.read_csv(os.path.join(file_path, file_series))
    df_dicom_study = pd.read_csv(os.path.join(file_path, file_study))
    
    series_cols = df_dicom_series.columns
    study_cols = df_dicom_study.columns
    
    common_cols = series_cols.intersection(study_cols)
    series_not_study = series_cols.difference(study_cols)
    study_not_series = study_cols.difference(series_cols)
    
    df_all = pd.merge(df_dicom_series, df_dicom_study, how="outer", on=common_cols.to_list())
    df = df_all[extract_cols]
    
    if output_file:
        df.to_excel(output_file, index=False)
    
    return df_all, df, df_dicom_series, df_dicom_study

# %%
file_path = "../Data/Lee, Ju Hun's files - R3Data"

file_series = "dicomtocsv_series.csv"
file_study = "dicomtocsv_study.csv"
# output_file = "../Data/output.xlsx"

extract_cols = ['PatientID', 'AccessionNumber', 'PatientBirthDate', 'PatientAge', 'PatientSex',
        'StudyDate', 'StudyTime', 'AcquisitionDate',
        'Modality', 'Manufacturer', 'ManufacturerModelName',
        'StudyDescription', 'SeriesNumber', 'SeriesDescription',
        'Exposure',
        'Rows', 'Columns', 'PixelSpacing',
        'Modality', 'Manufacturer', 'ManufacturerModelName']

df_all, df, df_dicom_series, df_dicom_study = merge_and_extract(file_path, file_series, file_study, None, extract_cols)

# %%
df_dicom_series
# Out:
#         NumberOfReferences                                   ImageType  \
# 0                        1                             DERIVED\PRIMARY
# 1                        1                           DERIVED\SECONDARY
# 2                        1                             DERIVED\PRIMARY
# 3                        1                             DERIVED\PRIMARY
# 4                        1                             DERIVED\PRIMARY
# ...                    ...                                         ...
# 136194                   1                           DERIVED\SECONDARY
# 136195                   1                             DERIVED\PRIMARY
# 136196                   1                             DERIVED\PRIMARY
# 136197                   1  DERIVED\PRIMARY\TOMOSYNTHESIS\GENERATED_2D
# 136198                   1  DERIVED\PRIMARY\TOMOSYNTHESIS\GENERATED_2D
#
#                         SOPClassUID   StudyDate AcquisitionDate  \
# 0       1.2.840.10008.5.1.4.1.1.1.2  2015-01-02      2015-01-02
# 1         1.2.840.10008.5.1.4.1.1.7  2015-01-02             NaN
# 2       1.2.840.10008.5.1.4.1.1.1.2  2015-01-02      2015-01-02
# 3       1.2.840.10008.5.1.4.1.1.1.2  2015-01-02      2015-01-02
# 4       1.2.840.10008.5.1.4.1.1.1.2  2015-01-02      2015-01-02
# ...                             ...         ...             ...
# 136194    1.2.840.10008.5.1.4.1.1.7  2022-12-29             NaN
# 136195  1.2.840.10008.5.1.4.1.1.1.2  2022-12-29      2022-12-29
# 136196  1.2.840.10008.5.1.4.1.1.1.2  2022-12-29      2022-12-29
# 136197  1.2.840.10008.5.1.4.1.1.1.2  2022-12-29             NaN
# 136198  1.2.840.10008.5.1.4.1.1.1.2  2022-12-29             NaN
#
#        AcquisitionDateTime StudyTime  AccessionNumber Modality  \
# 0                      NaN  08:39:23         80861023       MG
# 1                      NaN  11:30:52         81776067       MG
# 2                      NaN  11:30:52         81776067       MG
# 3                      NaN  11:30:52         81776067       MG
# 4                      NaN  11:30:52         81776067       MG
# ...                    ...       ...              ...      ...
# 136194                 NaN  03:17:31        451098158       MG
# 136195                 NaN  03:17:30        451098158       MG
# 136196                 NaN  03:17:30        451098158       MG
# 136197                 NaN  03:17:30        451098158       MG
# 136198                 NaN  03:17:30        451098158       MG
#
#                Manufacturer  \
# 0             HOLOGIC, Inc.
# 1       R2 Technology, Inc.
# 2             HOLOGIC, Inc.
# 3             HOLOGIC, Inc.
# 4             HOLOGIC, Inc.
# ...                     ...
# 136194        HOLOGIC, Inc.
# 136195        HOLOGIC, Inc.
# 136196        HOLOGIC, Inc.
# 136197        HOLOGIC, Inc.
# 136198        HOLOGIC, Inc.
#
#                                          StudyDescription  \
# 0       BREAST IMAGING TOMOSYNTHESIS DIAGNOSTIC BILATERAL
# 1             DIAG MAMMO - DIRECT DIG IMAGE BIL ALL VIEWS
# 2                              MAMMOGRAM DIGITAL DX BILAT
# 3                              MAMMOGRAM DIGITAL DX BILAT
# 4                              MAMMOGRAM DIGITAL DX BILAT
# ...                                                   ...
# 136194    DIAGNOSTIC RIGHT UNILATERAL MAMMOGRAM WITH TOMO
# 136195    DIAGNOSTIC RIGHT UNILATERAL MAMMOGRAM WITH TOMO
# 136196    DIAGNOSTIC RIGHT UNILATERAL MAMMOGRAM WITH TOMO
# 136197    DIAGNOSTIC RIGHT UNILATERAL MAMMOGRAM WITH TOMO
# 136198    DIAGNOSTIC RIGHT UNILATERAL MAMMOGRAM WITH TOMO
#
#                      SeriesDescription ManufacturerModelName  PatientName  \
# 0                                L ISO    Selenia Dimensions          NaN
# 1                            R2 CAD SC                Cenova          NaN
# 2                                 L CC    Selenia Dimensions          NaN
# 3                                L MLO    Selenia Dimensions          NaN
# 4                                 R CC    Selenia Dimensions          NaN
# ...                                ...                   ...          ...
# 136194  Hologic R2 ImageChecker CAD SC    Selenia Dimensions          NaN
# 136195                            R ML    Selenia Dimensions          NaN
# 136196                            R CC    Selenia Dimensions          NaN
# 136197            R MLO Intelligent 2D    Selenia Dimensions          NaN
# 136198             R CC Intelligent 2D    Selenia Dimensions          NaN
#
#          PatientID  IssuerOfPatientID PatientBirthDate PatientSex  \
# 0       4333469193                NaN       1964-07-01          F
# 1       4333843993                NaN       1967-07-01          F
# 2       4333843993                NaN       1967-07-01          F
# 3       4333843993                NaN       1967-07-01          F
# 4       4333843993                NaN       1967-07-01          F
# ...            ...                ...              ...        ...
# 136194  4333211581                NaN       1947-07-01          F
# 136195  4333211581                NaN       1947-07-01          F
# 136196  4333211581                NaN       1947-07-01          F
# 136197  4333211581                NaN       1947-07-01          F
# 136198  4333211581                NaN       1947-07-01          F
#
#         OtherPatientIDs ScanningSequence SequenceVariant ScanOptions  \
# 0                   NaN              NaN             NaN         NaN
# 1                   NaN              NaN             NaN         NaN
# 2                   NaN              NaN             NaN         NaN
# 3                   NaN              NaN             NaN         NaN
# 4                   NaN              NaN             NaN         NaN
# ...                 ...              ...             ...         ...
# 136194              NaN              NaN             NaN         NaN
# 136195              NaN              NaN             NaN         NaN
# 136196              NaN              NaN             NaN         NaN
# 136197              NaN              NaN             NaN         NaN
# 136198              NaN              NaN             NaN         NaN
#
#        MRAcquisitionType SequenceName  SliceThickness  MagneticFieldStrength  \
# 0                    NaN          NaN             NaN                    NaN
# 1                    NaN          NaN             NaN                    NaN
# 2                    NaN          NaN             NaN                    NaN
# 3                    NaN          NaN             NaN                    NaN
# 4                    NaN          NaN             NaN                    NaN
# ...                  ...          ...             ...                    ...
# 136194               NaN          NaN             NaN                    NaN
# 136195               NaN          NaN             NaN                    NaN
# 136196               NaN          NaN             NaN                    NaN
# 136197               NaN          NaN             NaN                    NaN
# 136198               NaN          NaN             NaN                    NaN
#
#         SpacingBetweenSlices  ProtocolName  Exposure  ConvolutionKernel  \
# 0                        NaN           NaN      27.0                NaN
# 1                        NaN           NaN       NaN                NaN
# 2                        NaN           NaN     246.0                NaN
# 3                        NaN           NaN     250.0                NaN
# 4                        NaN           NaN     197.0                NaN
# ...                      ...           ...       ...                ...
# 136194                   NaN           NaN       NaN                NaN
# 136195                   NaN           NaN     102.0                NaN
# 136196                   NaN           NaN     109.0                NaN
# 136197                   NaN           NaN      60.0                NaN
# 136198                   NaN           NaN      50.0                NaN
#
#         MREchoSequence  StudyInstanceUID  SeriesInstanceUID   StudyID  \
# 0                  NaN          1.400756           1.882280  1.113140
# 1                  NaN          1.233100           1.347473  1.119129
# 2                  NaN          1.233100           1.936507  1.119129
# 3                  NaN          1.233100           1.220605  1.119129
# 4                  NaN          1.233100           1.340178  1.119129
# ...                ...               ...                ...       ...
# 136194             NaN          1.114255           1.277641  1.310636
# 136195             NaN          1.114255           1.336870  1.310636
# 136196             NaN          1.114255           1.140919  1.310636
# 136197             NaN          1.114255           1.278132  1.310636
# 136198             NaN          1.114255           1.180501  1.310636
#
#         SeriesNumber  InstanceNumber  NumberOfFrames    Rows  Columns  \
# 0         71100000.0           367.0             NaN  4096.0   3328.0
# 1                1.0             1.0             NaN  1500.0   1250.0
# 2         71300000.0            87.0             NaN  4096.0   3328.0
# 3         71300000.0            93.0             NaN  4096.0   3328.0
# 4         71300000.0            75.0             NaN  4096.0   3328.0
# ...              ...             ...             ...     ...      ...
# 136194         745.0             1.0             NaN  1500.0   1250.0
# 136195    71100000.0           427.0             NaN  3328.0   2560.0
# 136196    71100000.0           425.0             NaN  3328.0   2560.0
# 136197    71300000.0           422.0             NaN  3328.0   2560.0
# 136198    71300000.0           415.0             NaN  3328.0   2560.0
#
#              PixelSpacing  BurnedInAnnotation  \
# 0       0.065238\0.065238                 NaN
# 1                     NaN                 NaN
# 2       0.065238\0.065238                 NaN
# 3       0.065238\0.065238                 NaN
# 4       0.065238\0.065238                 NaN
# ...                   ...                 ...
# 136194                NaN                 NaN
# 136195  0.038889\0.038889                 NaN
# 136196  0.038889\0.038889                 NaN
# 136197  0.064744\0.064744                 NaN
# 136198  0.065045\0.065045                 NaN
#
#              WindowCenterWidthExplanation       TransferSyntaxUID
# 0                                     NaN  1.2.840.10008.1.2.4.70
# 1                                     NaN     1.2.840.10008.1.2.1
# 2                                     NaN  1.2.840.10008.1.2.4.70
# 3                                     NaN  1.2.840.10008.1.2.4.70
# 4                                     NaN  1.2.840.10008.1.2.4.70
# ...                                   ...                     ...
# 136194                                NaN     1.2.840.10008.1.2.1
# 136195                                NaN  1.2.840.10008.1.2.4.70
# 136196                                NaN  1.2.840.10008.1.2.4.70
# 136197  Normal\High contrast\Low contrast  1.2.840.10008.1.2.4.70
# 136198  Normal\High contrast\Low contrast  1.2.840.10008.1.2.4.70
#
# [136199 rows x 43 columns]

# %%
df_dicom_study
# Out:
#         StudyDate StudyTime  AccessionNumber Modality         Manufacturer  \
# 0      2015-01-02  08:39:23         80861023       MG        HOLOGIC, Inc.
# 1      2015-01-02  11:30:52         81776067       MG  R2 Technology, Inc.
# 2      2015-01-02  13:47:42         80984343       MG  R2 Technology, Inc.
# 3      2015-01-02  18:52:08         80861023       MG  R2 Technology, Inc.
# 4      2015-01-05  02:21:18         80113862       MG  R2 Technology, Inc.
# ...           ...       ...              ...      ...                  ...
# 15556  2022-12-13  02:14:40        459321381       MG        HOLOGIC, Inc.
# 15557  2022-12-19  11:38:02        450005908       MG        HOLOGIC, Inc.
# 15558  2022-12-22  18:46:26        459297287       MG        HOLOGIC, Inc.
# 15559  2022-12-28  11:37:53        459166823       MG        HOLOGIC, Inc.
# 15560  2022-12-29  03:17:30        451098158       MG        HOLOGIC, Inc.
#
#        InstitutionName  InstitutionAddress  StationName  \
# 0                  NaN                 NaN          NaN
# 1                  NaN                 NaN          NaN
# 2                  NaN                 NaN          NaN
# 3                  NaN                 NaN          NaN
# 4                  NaN                 NaN          NaN
# ...                ...                 ...          ...
# 15556              NaN                 NaN          NaN
# 15557              NaN                 NaN          NaN
# 15558              NaN                 NaN          NaN
# 15559              NaN                 NaN          NaN
# 15560              NaN                 NaN          NaN
#
#                                         StudyDescription  \
# 0      BREAST IMAGING TOMOSYNTHESIS DIAGNOSTIC BILATERAL
# 1            DIAG MAMMO - DIRECT DIG IMAGE BIL ALL VIEWS
# 2             DIAG MAMMO - DIRECT DIG IMAGE LT ALL VIEWS
# 3      BREAST IMAGING TOMOSYNTHESIS DIAGNOSTIC BILATERAL
# 4      SCREENING MAMMOGRAPHY DIGITAL BILAT ALL VIEWS ...
# ...                                                  ...
# 15556                          SCREENING MAMMO WITH TOMO
# 15557                      SCREENING MAMMOGRAM WITH TOMO
# 15558     SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMO
# 15559                      SCREENING MAMMOGRAM WITH TOMO
# 15560    DIAGNOSTIC RIGHT UNILATERAL MAMMOGRAM WITH TOMO
#
#        InstitutionalDepartmentName PerformingPhysicianName  \
# 0                              NaN                     NaN
# 1                              NaN                     NaN
# 2                              NaN                     NaN
# 3                              NaN                     NaN
# 4                              NaN                     NaN
# ...                            ...                     ...
# 15556                          NaN                     NaN
# 15557                          NaN                     NaN
# 15558                          NaN                     NaN
# 15559                          NaN                     NaN
# 15560                          NaN                     NaN
#
#       ManufacturerModelName  PatientName   PatientID  IssuerOfPatientID  \
# 0        Selenia Dimensions          NaN  4333469193                NaN
# 1                    Cenova          NaN  4333843993                NaN
# 2                    Cenova          NaN  4334188890                NaN
# 3                    Cenova          NaN  4333469193                NaN
# 4                    Cenova          NaN  4333966965                NaN
# ...                     ...          ...         ...                ...
# 15556    Selenia Dimensions          NaN  4333662111                NaN
# 15557    Selenia Dimensions          NaN  4333233282                NaN
# 15558    Selenia Dimensions          NaN  4333740431                NaN
# 15559    Selenia Dimensions          NaN  4333966333                NaN
# 15560    Selenia Dimensions          NaN  4333211581                NaN
#
#       PatientBirthDate PatientSex  OtherPatientIDs PatientAge  \
# 0           1964-07-01          F              NaN       050Y
# 1           1967-07-01          F              NaN       047Y
# 2           1935-07-01          F              NaN       079Y
# 3           1964-07-01          F              NaN       050Y
# 4           1950-07-01          F              NaN       064Y
# ...                ...        ...              ...        ...
# 15556       1977-07-01          F              NaN       045Y
# 15557       1957-07-01          F              NaN       064Y
# 15558       1963-07-01          F              NaN       059Y
# 15559       1960-07-01          F              NaN       062Y
# 15560       1947-07-01          F              NaN       075Y
#
#       BodyPartExamined  ProtocolName  StudyInstanceUID  StudyStatusID
# 0               BREAST           NaN          1.400756            NaN
# 1               BREAST           NaN          1.233100            NaN
# 2               BREAST           NaN          1.115858            NaN
# 3               BREAST           NaN          1.328263            NaN
# 4               BREAST           NaN          1.143213            NaN
# ...                ...           ...               ...            ...
# 15556           BREAST           NaN          1.654537            NaN
# 15557           BREAST           NaN          1.122824            NaN
# 15558           BREAST           NaN          1.177395            NaN
# 15559           BREAST           NaN          1.309485            NaN
# 15560           BREAST           NaN          1.114255            NaN
#
# [15561 rows x 23 columns]

# %%
def group_by_patient(df, output_file):
    """
    Group dataframe by patient ID
    """    
    PIDs = df["PatientID"].unique()
    num_patient = PIDs.size
    
    count = 0
    for pid in PIDs:
        if count == 0: 
            tmp = df[df["PatientID"] == pid]
        else: 
            tmp = pd.concat([tmp, df[df["PatientID"] == pid]], ignore_index=True)
        count += 1
    
#     tmp.sort_values(by=['PatientID', 'StudyDate'], inplace=True, ignore_index=True)
    tmp.sort_values(by=['PatientID', 'StudyDate', 'AccessionNumber'], inplace=True, ignore_index=True)
    
    if output_file:
        tmp.to_excel(output_file, index=False)
    
    return num_patient, tmp

# %%
output_file = "../Data/dicom.xlsx"
num_patient, output = group_by_patient(df, None)

# %% [markdown]
# # **Add tags** (Study, Side, Series)

# %% [markdown]
# ### <span style="color:#FF6347;">**READ**</span> file

# %%
file_path = "../Data/dicom.xlsx"
dicom = pd.read_excel(file_path)

# %%
dicom
# Out:
#          PatientID  AccessionNumber PatientBirthDate PatientAge PatientSex  \
# 0       4330018595         60103700       1965-07-01       054Y          F
# 1       4330018595         60103700       1965-07-01        NaN          F
# 2       4330018595         60103700       1965-07-01        NaN          F
# 3       4330018595         60103700       1965-07-01        NaN          F
# 4       4330018595         60103700       1965-07-01        NaN          F
# ...            ...              ...              ...        ...        ...
# 136228  4339959661         62216536       1971-07-01        NaN          F
# 136229  4339959661         62216536       1971-07-01        NaN          F
# 136230  4339959661         62216536       1971-07-01        NaN          F
# 136231  4339959661         62216536       1971-07-01        NaN          F
# 136232  4339959661         62216536       1971-07-01        NaN          F
#
#          StudyDate StudyTime AcquisitionDate Modality  \
# 0       2020-06-02  09:10:52             NaN       MG
# 1       2020-06-02  09:10:51             NaN       MG
# 2       2020-06-02  09:10:51      2020-06-02       MG
# 3       2020-06-02  09:10:51             NaN       MG
# 4       2020-06-02  09:10:51             NaN       MG
# ...            ...       ...             ...      ...
# 136228  2019-10-28  02:45:37      2019-10-28       MG
# 136229  2019-10-28  02:45:37      2019-10-28       MG
# 136230  2019-10-28  02:45:37      2019-10-28       MG
# 136231  2019-10-28  18:20:08             NaN       PR
# 136232  2019-10-28  18:20:08             NaN       PR
#
#                    Manufacturer ManufacturerModelName  \
# 0           R2 Technology, Inc.                Cenova
# 1           R2 Technology, Inc.                Cenova
# 2                 HOLOGIC, Inc.    Selenia Dimensions
# 3                 HOLOGIC, Inc.    Selenia Dimensions
# 4                 HOLOGIC, Inc.    Selenia Dimensions
# ...                         ...                   ...
# 136228            HOLOGIC, Inc.    Selenia Dimensions
# 136229            HOLOGIC, Inc.    Selenia Dimensions
# 136230            HOLOGIC, Inc.    Selenia Dimensions
# 136231  Philips Medical Systems      iSite Enterprise
# 136232  Philips Medical Systems      iSite Enterprise
#
#                                          StudyDescription  SeriesNumber  \
# 0       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS           1.0
# 1       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS           1.0
# 2       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS    71100000.0
# 3       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS    71300000.0
# 4       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS    71300000.0
# ...                                                   ...           ...
# 136228  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN    72100000.0
# 136229  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN    72100000.0
# 136230  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN    72100000.0
# 136231  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN           1.0
# 136232  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN           1.0
#
#                      SeriesDescription  Exposure    Rows  Columns  \
# 0       Hologic R2 ImageChecker CAD SC       NaN  1500.0   1250.0
# 1       Hologic R2 ImageChecker CAD SC       NaN  1500.0   1250.0
# 2                                 R ML     126.0  3328.0   2560.0
# 3                R XCCL Intelligent 2D      63.0  3328.0   2560.0
# 4                  R ML Intelligent 2D      57.0  3328.0   2560.0
# ...                                ...       ...     ...      ...
# 136228   L CC Tomosynthesis Projection      72.0   425.0    266.0
# 136229   R CC Tomosynthesis Projection      74.0   425.0    266.0
# 136230  L MLO Tomosynthesis Projection      78.0   425.0    266.0
# 136231                       5DBAD14E0       NaN     NaN      NaN
# 136232                       5DBAD14E0       NaN     NaN      NaN
#
#              PixelSpacing
# 0                     NaN
# 1                     NaN
# 2       0.038889\0.038889
# 3       0.064318\0.064318
# 4       0.064619\0.064619
# ...                   ...
# 136228                NaN
# 136229                NaN
# 136230                NaN
# 136231                NaN
# 136232                NaN
#
# [136233 rows x 18 columns]

# %%
dicom["Modality"].unique()
# Out:
# array(['MG', 'PR', 'SR', 'US', 'MR', 'OT', 'KO', 'SC'], dtype=object)

# %%
laterality_bi = ["BILATERAL", "BILAT", "BIL", "BI"]
laterality_uni = ["UNILATERAL", "UNILAT", "UNI", "Unilateral"]
other = ["IMPLANT", "CONTRAST ENHANCED", "Implant"]

# %%
dicom_copy = dicom.copy()

# %% [markdown]
# ### <span style="color:blue"> **Study**</span> (SCREEN, DIAG)

# %%
study_screen = ["SCREENING", "SCREEN", "Screening"]
study_diag = ["DIAG", "DIAGNOSTIC", "DX", "Diagnostic"]

# %%
# Assuming your DataFrame is named 'df' and the column where you found the words is 'Notes'
column_to_check = 'StudyDescription' 
type_column = 'study'

# Ensure the column is treated as strings and handle missing values
dicom_copy[column_to_check] = dicom_copy[column_to_check].astype(str)

# ---Create the OR-Condition Mask ---
# The pattern uses the '|' (OR) symbol.
# We use .str.contains() with case=False to handle both "DIAG" and "Diagnostic".
diag_terms = [term for term in study_diag]
diag_pattern = '|'.join([re.escape(term) for term in diag_terms])

screen_terms = [term for term in study_screen]
screen_pattern = '|'.join([re.escape(term) for term in screen_terms])

# Create a boolean mask: True if the string contains either word (case-insensitive)
diag_mask = dicom_copy[column_to_check].str.contains(diag_pattern, case=False, na=False, regex=True)
screen_mask = dicom_copy[column_to_check].str.contains(screen_pattern, case=False, na=False, regex=True)

# --- Assign the value "DIAG" to the 'type' column ---
# Use .loc to assign the value only where the mask is True
dicom_copy.loc[diag_mask, type_column] = "DIAG"
dicom_copy.loc[screen_mask, type_column] = "SCREEN"

# %% [markdown]
# ### <span style="color:blue">**Side**</span> (R, L)

# %%
side_right = ["RIGHT", "RT", "Right", "R XCCL", "R MLO", "R CC", "R ML", "R SIO", "R LM"]
side_left = ["LEFT", "LT", "Left", "L XCCL", "L MLO", "L CC", "L ML", "L SIO", "L LM"]

# %%
# Assuming your DataFrame is named 'df' and the column where you found the words is 'Notes'
column_to_check = 'SeriesDescription' 
type_column = 'side'

# Ensure the column is treated as strings and handle missing values
dicom_copy[column_to_check] = dicom_copy[column_to_check].astype(str)

# ---Create the OR-Condition Mask ---
# The pattern uses the '|' (OR) symbol.
# We use .str.contains() with case=False to handle both "DIAG" and "Diagnostic".
side_right_terms = [term for term in side_right]
side_right_pattern = '|'.join([re.escape(term) for term in side_right_terms])

side_left_terms = [term for term in side_left]
side_left_pattern = '|'.join([re.escape(term) for term in side_left_terms])

# Create a boolean mask: True if the string contains either word (case-insensitive)
side_right_mask = dicom_copy[column_to_check].str.contains(side_right_pattern, case=False, na=False, regex=True)
side_left_mask = dicom_copy[column_to_check].str.contains(side_left_pattern, case=False, na=False, regex=True)


# --- Assign the value "DIAG" to the 'type' column ---
# Use .loc to assign the value only where the mask is True
dicom_copy.loc[side_right_mask, type_column] = "R"
dicom_copy.loc[side_left_mask, type_column] = "L"

# %% [markdown]
# ### <span style="color:blue">**Series**</span> (DBT, IN2D, C VIEW, SECURE)

# %%
series_dbt = ["TOMOSYNTHESIS", "TOMOSYN", "TOMO", "TOMOHD", "TomoHD", "Tomosynthesis"]
series_in2d = ["Intelligent 2D"]
series_cview = ["C-View"]
series_secure = ["SecurView"]

# %%
# Assuming your DataFrame is named 'df' and the column where you found the words is 'Notes'
column_to_check = 'SeriesDescription' 
type_column = 'series'

# Ensure the column is treated as strings and handle missing values
dicom_copy[column_to_check] = dicom_copy[column_to_check].astype(str)

# ---Create the OR-Condition Mask ---
# The pattern uses the '|' (OR) symbol.
dbt_terms = [term for term in series_dbt]
dbt_pattern = '|'.join([re.escape(term) for term in dbt_terms])

in2d_terms = [term for term in series_in2d]
in2d_pattern = '|'.join([re.escape(term) for term in in2d_terms])

cview_terms = [term for term in series_cview]
cview_pattern = '|'.join([re.escape(term) for term in cview_terms])

secure_terms = [term for term in series_secure]
secure_pattern = '|'.join([re.escape(term) for term in secure_terms])

# Create a boolean mask: True if the string contains either word (case-insensitive)
dbt_mask = dicom_copy[column_to_check].str.contains(dbt_pattern, case=False, na=False, regex=True)
in2d_mask = dicom_copy[column_to_check].str.contains(in2d_pattern, case=False, na=False, regex=True)
cview_mask = dicom_copy[column_to_check].str.contains(cview_pattern, case=False, na=False, regex=True)
secure_mask = dicom_copy[column_to_check].str.contains(secure_pattern, case=False, na=False, regex=True)

# --- Assign the value "DBT" to the 'type' column ---
# Use .loc to assign the value only where the mask is True
dicom_copy.loc[dbt_mask, type_column] = "DBT"
dicom_copy.loc[in2d_mask, type_column] = "IN2D"
dicom_copy.loc[cview_mask, type_column] = "C VIEW"
dicom_copy.loc[secure_mask, type_column] = "SECURE"

# %%
dicom_copy
# Out:
#          PatientID  AccessionNumber PatientBirthDate PatientAge PatientSex  \
# 0       4330018595         60103700       1965-07-01       054Y          F
# 1       4330018595         60103700       1965-07-01        NaN          F
# 2       4330018595         60103700       1965-07-01        NaN          F
# 3       4330018595         60103700       1965-07-01        NaN          F
# 4       4330018595         60103700       1965-07-01        NaN          F
# ...            ...              ...              ...        ...        ...
# 136228  4339959661         62216536       1971-07-01        NaN          F
# 136229  4339959661         62216536       1971-07-01        NaN          F
# 136230  4339959661         62216536       1971-07-01        NaN          F
# 136231  4339959661         62216536       1971-07-01        NaN          F
# 136232  4339959661         62216536       1971-07-01        NaN          F
#
#          StudyDate StudyTime AcquisitionDate Modality  \
# 0       2020-06-02  09:10:52             NaN       MG
# 1       2020-06-02  09:10:51             NaN       MG
# 2       2020-06-02  09:10:51      2020-06-02       MG
# 3       2020-06-02  09:10:51             NaN       MG
# 4       2020-06-02  09:10:51             NaN       MG
# ...            ...       ...             ...      ...
# 136228  2019-10-28  02:45:37      2019-10-28       MG
# 136229  2019-10-28  02:45:37      2019-10-28       MG
# 136230  2019-10-28  02:45:37      2019-10-28       MG
# 136231  2019-10-28  18:20:08             NaN       PR
# 136232  2019-10-28  18:20:08             NaN       PR
#
#                    Manufacturer ManufacturerModelName  \
# 0           R2 Technology, Inc.                Cenova
# 1           R2 Technology, Inc.                Cenova
# 2                 HOLOGIC, Inc.    Selenia Dimensions
# 3                 HOLOGIC, Inc.    Selenia Dimensions
# 4                 HOLOGIC, Inc.    Selenia Dimensions
# ...                         ...                   ...
# 136228            HOLOGIC, Inc.    Selenia Dimensions
# 136229            HOLOGIC, Inc.    Selenia Dimensions
# 136230            HOLOGIC, Inc.    Selenia Dimensions
# 136231  Philips Medical Systems      iSite Enterprise
# 136232  Philips Medical Systems      iSite Enterprise
#
#                                          StudyDescription  SeriesNumber  \
# 0       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS           1.0
# 1       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS           1.0
# 2       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS    71100000.0
# 3       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS    71300000.0
# 4       DIAG DIG MAMMO RIGHT ALL VIEWS WITH TOMOSYNTHESIS    71300000.0
# ...                                                   ...           ...
# 136228  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN    72100000.0
# 136229  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN    72100000.0
# 136230  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN    72100000.0
# 136231  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN           1.0
# 136232  SCREENING MAMMOGRAPHY DIGITAL BILATERAL W TOMOSYN           1.0
#
#                      SeriesDescription  Exposure    Rows  Columns  \
# 0       Hologic R2 ImageChecker CAD SC       NaN  1500.0   1250.0
# 1       Hologic R2 ImageChecker CAD SC       NaN  1500.0   1250.0
# 2                                 R ML     126.0  3328.0   2560.0
# 3                R XCCL Intelligent 2D      63.0  3328.0   2560.0
# 4                  R ML Intelligent 2D      57.0  3328.0   2560.0
# ...                                ...       ...     ...      ...
# 136228   L CC Tomosynthesis Projection      72.0   425.0    266.0
# 136229   R CC Tomosynthesis Projection      74.0   425.0    266.0
# 136230  L MLO Tomosynthesis Projection      78.0   425.0    266.0
# 136231                       5DBAD14E0       NaN     NaN      NaN
# 136232                       5DBAD14E0       NaN     NaN      NaN
#
#              PixelSpacing   study side series
# 0                     NaN    DIAG  NaN    NaN
# 1                     NaN    DIAG  NaN    NaN
# 2       0.038889\0.038889    DIAG    R    NaN
# 3       0.064318\0.064318    DIAG    R   IN2D
# 4       0.064619\0.064619    DIAG    R   IN2D
# ...                   ...     ...  ...    ...
# 136228                NaN  SCREEN    L    DBT
# 136229                NaN  SCREEN    R    DBT
# 136230                NaN  SCREEN    L    DBT
# 136231                NaN  SCREEN  NaN    NaN
# 136232                NaN  SCREEN  NaN    NaN
#
# [136233 rows x 21 columns]

# %% [markdown]
# ### <span style="color:#FF6347;">**SAVE**</span> file

# %%
output_file = os.path.join("../Data/",'dicom_tag' + ".xlsx")
dicom_copy.to_excel(output_file, index=False)

# %% [markdown]
# ### <span style="color:#FF6347;">**READ**</span> file

# %%
file_path = os.path.join("../Data/",'dicom_tag' + ".xlsx")
dicom = pd.read_excel(file_path)

# %%
dicom[dicom["series"]=="DBT"]["PatientID"].unique().size
# Out:
# 759

# %%
import pandas as pd
import os
import numpy as np
import re

# %%
file_path = "P:/Dataset/R01-MO-DBT/MO-DBT-data-curation/Cancer/Cleaned/enteredit_findings.xlsx"
cancer = pd.read_excel(file_path)

# %%
file_path = "P:/Dataset/R01-MO-DBT/MO-DBT-data-curation/Control/Cleaned/enteredit_findings.xlsx"
control = pd.read_excel(file_path)

# %%
cancer.head(5)
# Out:
#    PATIENT_STUDY_ID  ACCESSION_NUMBER                   COMPOSITION_NAME  \
# 0        4330018595          63027507  Heterogeneously dense (51% - 75%)
# 1        4330018595          63737104  Heterogeneously dense (51% - 75%)
# 2        4330018595          63737104  Heterogeneously dense (51% - 75%)
# 3        4330018595          60690108  Heterogeneously dense (51% - 75%)
# 4        4330018595          60103700  Heterogeneously dense (51% - 75%)
#
#   FINDING_LOCATION                                   FINDING_CATEGORY  \
# 0              NaN             0 - Need additional imaging evaluation
# 1              NaN                                 2 - Benign finding
# 2              NaN     3 - Probably benign - short interval follow-up
# 3              NaN                                 2 - Benign finding
# 4              NaN  5 - Highly suggestive of malignancy, appropria...
#
#                                    FINDING_REC EXAM_COMPLETED_DATE  \
# ...

# %%
cancer_pids = set(cancer["PATIENT_STUDY_ID"].unique())

# %%
control_pids = set(control["PATIENT_STUDY_ID"].unique())

# %%
len(control_pids - cancer_pids)
# Out:
# 37977

# %%
len(cancer_pids - control_pids)
# Out:
# 8904

# %%
import pandas as pd
import os
# Out:
# /Users/tracyliu/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ### Files

# %% [markdown]
# See **parameter explanation for detail information

# %%
file_path = "../Data/parameters of interest.xlsx"
files = pd.ExcelFile(file_path).sheet_names

# %%
files
# Out:
# ['pathology',
#  'pathology_findings',
#  'family_hx',
#  'patient_demo',
#  'vitals',
#  'risk_factors',
#  'enteredit_findings',
#  'hormonal_mens']

# %%
shared_path = "../Data/R3Data"

# %% [markdown]
# #### 7. enteredit_findings

# %%
idx = 7
file = files[idx-1]
print(file)
extract_cols = pd.read_excel(file_path, sheet_name=file)["Name"].tolist()
print(extract_cols)
# Out:
# enteredit_findings
# ['PATIENT_STUDY_ID', 'ACCESSION_NUMBER', 'COMPOSITION_NAME', 'FINDING_LOCATION', 'FINDING_CATEGORY', 'FINDING_REC', 'EXAM_COMPLETED_DATE']

# %%
file_names = [
    str(file) + ".txt", 
    str(file) + ".csv",
    str(file) + ".csv"
]
file_names
# Out:
# ['pathology.txt', 'pathology.csv', 'pathology.csv']

# %% [markdown]
# ### Cancer

# %%
study = "Cancer"
folder = ["R3_3787_Lee_Cancer_Extract_Files", "R3_3787_Lee_Data_Cancer_20240509", "R3_3787_Lee_Data_Cancer_20250912"]

# %%
final_unique_dfs = [] # List to hold the de-duplicated data from each file

# 2. Process each file
for i, file_name in enumerate(file_names):
    file_extension = os.path.splitext(file_name)[1].lower()
    file_path = os.path.join(shared_path, study, folder[i], file_name)
    
    if file_extension == '.csv':
        current_df = pd.read_csv(file_path, encoding='latin-1')
    elif file_extension == '.txt':
        current_df = pd.read_csv(file_path, sep='|')
    else:
        continue

    # --- KEY LOGIC FOR INTER-FILE DEDUPLICATION ---
    
    # Concatenate the current file's data with all previously processed data
    # (Do NOT use ignore_index=True here, we need separate indices for now)
    
    if final_unique_dfs:
        # Create a temporary DataFrame of ALL data processed so far
        all_prior_data = pd.concat(final_unique_dfs)
        
        # Check the current_df against all prior data. 
        # We only look at the columns that contain the actual data (excluding the index).
        data_columns = current_df.columns
        
        # Identify rows in the current file that are NOT duplicates of PRIOR files
        # The 'indicator=True' is used to identify the source of the merge
        merged = pd.merge(
            current_df, 
            all_prior_data, 
            on=list(data_columns), # Merge on all data columns
            how='left', 
            indicator=True
        )
        
        # Rows in the current file that are *only* in the 'left' (current_df) are unique
        unique_to_current_file = merged[merged['_merge'] == 'left_only'].drop(columns='_merge')
        
        # Append the unique data (which includes any intra-file duplicates)
        final_unique_dfs.append(unique_to_current_file)
    else:
        # The first file is added as is (it has no prior files to check against)
        final_unique_dfs.append(current_df)


# 3. Final Concatenation
if final_unique_dfs:
    # Concatenate the final list of DataFrames to produce the result
    final_df = pd.concat(final_unique_dfs, ignore_index=True)

    print("✅ Successfully merged and removed ONLY inter-file duplicates.")
    print("\nFinal DataFrame head (includes intra-file duplicates):")
else:
    print("❌ No valid files were read. The final DataFrame is empty.")
# Out:
# ✅ Successfully merged and removed ONLY inter-file duplicates.
#
# Final DataFrame head (includes intra-file duplicates):

# %%
final_df
# Out:
#         PATIENT_STUDY_ID  ACCESSION_NUMBER ORG_CODE  INTERNAL_EXAM_ID  \
# 0             4334469937          69423837   MWHOAK          83749463
# 1             4334469937          69423837   MWHOAK          83749463
# 2             4334469937          69511096   MWHMNV          83836589
# 3             4334469937          69525464   MWHMNV          83841700
# 4             4334469937          69525464   MWHMNV          83841700
# ...                  ...               ...      ...               ...
# 173108        4333260965         451934907   HMTHIC          74229878
# 173109        4333119414         450097209   MWHMNV          73368129
# 173110        4333119414         450097209   MWHMNV          73368129
# 173111        4334331716         450009554   MWHMNV          73370350
# 173112        4334331716         450009554   MWHMNV          73370350
#
#         PATIENT_ID                   COMPOSITION_NAME FINDING_LOCATION  \
# 0          1152783  Heterogeneously dense (51% - 75%)              NaN
# 1          1152783  Heterogeneously dense (51% - 75%)              NaN
# 2          1152783                                NaN              NaN
# 3          1152783  Heterogeneously dense (51% - 75%)              NaN
# 4          1152783  Heterogeneously dense (51% - 75%)              NaN
# ...            ...                                ...              ...
# 173108     6155024  Heterogeneously dense (51% - 75%)              NaN
# 173109     2186707  Heterogeneously dense (51% - 75%)              NaN
# 173110     2186707  Heterogeneously dense (51% - 75%)              NaN
# 173111     1210201  Heterogeneously dense (51% - 75%)              NaN
# 173112     1210201  Heterogeneously dense (51% - 75%)              NaN
#
#                                          FINDING_CATEGORY  \
# 0                                      2 - Benign finding
# 1                      6 - Known biopsy proven malignancy
# 2                                                     NaN
# 3       5 - Highly suggestive of malignancy, appropria...
# 4                                            1 - Negative
# ...                                                   ...
# 173108                                 2 - Benign finding
# 173109                                 2 - Benign finding
# 173110                                 2 - Benign finding
# 173111                                 2 - Benign finding
# 173112                                 2 - Benign finding
#
#                                  FINDING_REC EXAM_COMPLETED_DATE
# 0                N-Normal interval follow-up          06/25/2020
# 1       K-Appropriate action should be taken          06/25/2020
# 2                                        NaN          06/09/2020
# 3              B-Biopsy should be considered          06/09/2020
# 4                N-Normal interval follow-up          06/09/2020
# ...                                      ...                 ...
# 173108           N-Normal interval follow-up          12/28/2022
# 173109           N-Normal interval follow-up          12/27/2022
# 173110           N-Normal interval follow-up          12/27/2022
# 173111           N-Normal interval follow-up          12/21/2022
# 173112           N-Normal interval follow-up          12/21/2022
#
# [173113 rows x 10 columns]

# %%
final_df['EXAM_COMPLETED_DATE'] = pd.to_datetime(final_df['EXAM_COMPLETED_DATE'], format='%m/%d/%Y')
final_df['EXAM_COMPLETED_DATE'] = final_df['EXAM_COMPLETED_DATE'].dt.strftime('%Y-%m-%d')

# %%
final_df.sort_values(by=['PATIENT_STUDY_ID', 'EXAM_COMPLETED_DATE', 'ACCESSION_NUMBER', "FINDING_CATEGORY"], ascending=[True, True, False, True], inplace=True, ignore_index=True)

# %%
final_df.dropna(subset=['COMPOSITION_NAME', 'FINDING_LOCATION', 'FINDING_CATEGORY', 'FINDING_REC'], how='all', inplace=True)

# %% [markdown]
# #### <span style="color: blue;">Remove duplicated entries, add a column marked how many duplicates </span>
#
# **Before drop duplicate = <span style="color: blue;">final_df</span> , after drop duplicate = <span style="color: blue;">unique_df</span>**

# %%
unique_df = final_df.copy()

# %%
unique_df['duplicate_count'] = unique_df.groupby(unique_df.columns.tolist(), dropna=False).transform('size')

# %%
unique_df = unique_df.drop_duplicates(subset=unique_df.columns.tolist(), keep = 'first').reset_index(drop = True)

# %%
unique_extract_cols = extract_cols + ['duplicate_count']

# %%
unique_df[unique_df["PATIENT_STUDY_ID"]==4330018595]
# Out:
#    PATIENT_STUDY_ID  ACCESSION_NUMBER ORG_CODE  INTERNAL_EXAM_ID  PATIENT_ID  \
# 0        4330018595          63027507   MWHNTH          90728533     9654707
# 1        4330018595          63737104   MWHNTH          99424137     9654707
# 2        4330018595          63737104   MWHNTH          99424137     9654707
# 3        4330018595          60690108   MWHNTH          83905509     9654707
# 4        4330018595          60103700   MWHNTH          83422682     9654707
# 5        4330018595          69461777   MWHOAK          83657913     9654707
# 6        4330018595          69461777   MWHOAK          83657913     9654707
# 7        4330018595          69058456   MWHOAK          82349369     9654707
# 8        4330018595          66064198   MWHNTH          89243522     9654707
# 9        4330018595         452973800   MWHNTH          75260336     9654707
#
#                     COMPOSITION_NAME FINDING_LOCATION  \
# 0  Heterogeneously dense (51% - 75%)              NaN
# 1  Heterogeneously dense (51% - 75%)              NaN
# 2  Heterogeneously dense (51% - 75%)              NaN
# 3  Heterogeneously dense (51% - 75%)              NaN
# 4  Heterogeneously dense (51% - 75%)              NaN
# 5  Heterogeneously dense (51% - 75%)              NaN
# 6  Heterogeneously dense (51% - 75%)              NaN
# 7  Heterogeneously dense (51% - 75%)              NaN
# 8  Heterogeneously dense (51% - 75%)              NaN
# 9  Heterogeneously dense (51% - 75%)              NaN
#
#                                     FINDING_CATEGORY  \
# 0             0 - Need additional imaging evaluation
# 1                                 2 - Benign finding
# 2     3 - Probably benign - short interval follow-up
# 3                                 2 - Benign finding
# 4  5 - Highly suggestive of malignancy, appropria...
# 5                                 2 - Benign finding
# 6                 6 - Known biopsy proven malignancy
# 7  99 - Post procedure mammograms for marker plac...
# 8                                 2 - Benign finding
# 9                                 2 - Benign finding
#
#                                         FINDING_REC EXAM_COMPLETED_DATE  \
# 0                          P-Additional projections          2019-07-26
# 1                       N-Normal interval follow-up          2019-08-19
# 2       F-Follow-up at short interval (1-11 months)          2019-08-19
# 3                       N-Normal interval follow-up          2020-06-02
# 4                     B-Biopsy should be considered          2020-06-02
# 5                       N-Normal interval follow-up          2020-06-30
# 6              K-Appropriate action should be taken          2020-06-30
# 7  X-Follow-up post biopsy as directed by clinician          2020-07-29
# 8                       N-Normal interval follow-up          2021-06-08
# 9                       N-Normal interval follow-up          2022-06-09
#
#    duplicate_count
# 0                2
# 1                1
# 2                1
# 3                1
# 4                2
# 5                1
# 6                1
# 7                1
# 8                2
# 9                2

# %%
unique_df[unique_extract_cols]
# Out:
#        PATIENT_STUDY_ID  ACCESSION_NUMBER  \
# 0            4330018595          63027507
# 1            4330018595          63737104
# 2            4330018595          63737104
# 3            4330018595          60690108
# 4            4330018595          60103700
# ...                 ...               ...
# 87216        4339959661          62216536
# 87217        4339959661          68434457
# 87218        4339959661         454148687
# 87219        4339959661         454148687
# 87220        4339959661         454612462
#
#                            COMPOSITION_NAME FINDING_LOCATION  \
# 0         Heterogeneously dense (51% - 75%)              NaN
# 1         Heterogeneously dense (51% - 75%)              NaN
# 2         Heterogeneously dense (51% - 75%)              NaN
# 3         Heterogeneously dense (51% - 75%)              NaN
# 4         Heterogeneously dense (51% - 75%)              NaN
# ...                                     ...              ...
# 87216     Heterogeneously dense (51% - 75%)              NaN
# 87217  Scattered fibroglandular (25% - 50%)              NaN
# 87218     Heterogeneously dense (51% - 75%)              NaN
# 87219     Heterogeneously dense (51% - 75%)              NaN
# 87220     Heterogeneously dense (51% - 75%)              NaN
#
#                                         FINDING_CATEGORY  \
# 0                 0 - Need additional imaging evaluation
# 1                                     2 - Benign finding
# 2         3 - Probably benign - short interval follow-up
# 3                                     2 - Benign finding
# 4      5 - Highly suggestive of malignancy, appropria...
# ...                                                  ...
# 87216                                 2 - Benign finding
# 87217                                       1 - Negative
# 87218             0 - Need additional imaging evaluation
# 87219                                       1 - Negative
# 87220  4A - Suspicious abnormality - biopsy should be...
#
#                                        FINDING_REC EXAM_COMPLETED_DATE  \
# 0                         P-Additional projections          2019-07-26
# 1                      N-Normal interval follow-up          2019-08-19
# 2      F-Follow-up at short interval (1-11 months)          2019-08-19
# 3                      N-Normal interval follow-up          2020-06-02
# 4                    B-Biopsy should be considered          2020-06-02
# ...                                            ...                 ...
# 87216                  N-Normal interval follow-up          2019-10-28
# 87217                  N-Normal interval follow-up          2020-11-09
# 87218                     P-Additional projections          2021-11-10
# 87219                  N-Normal interval follow-up          2021-11-10
# 87220                B-Biopsy should be considered          2021-11-15
#
#        duplicate_count
# 0                    2
# 1                    1
# 2                    1
# 3                    1
# 4                    2
# ...                ...
# 87216                2
# 87217                2
# 87218                1
# 87219                1
# 87220                1
#
# [87221 rows x 8 columns]

# %%
# output_file = os.path.join("../Data/", study, "Cleaned", file + ".xlsx")
# final_df[extract_cols].to_excel(output_file, index=False)

output_file = os.path.join("../Data/", study, "Cleaned", file + ".xlsx")
unique_df[unique_extract_cols].to_excel(output_file, index=False)
# Out:
# <ipython-input-18-21156de58b2d>:5: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.7' currently installed).
#   unique_df[unique_extract_cols].to_excel(output_file, index=False)

# %% [markdown]
# ### Control

# %%
study = "Control"
folder = ["R3_3787_Lee_Control_Extract_Files", "R3_3787_Lee_Data_Controls_20240508"]

# %%
final_unique_dfs = [] # List to hold the de-duplicated data from each file

file_names = [
    "enteredit_findings_controls.txt",
    "enteredit_findings_controls.csv"
]

# 2. Process each file
for i, file_name in enumerate(file_names):
    file_extension = os.path.splitext(file_name)[1].lower()
    file_path = os.path.join(shared_path, study, folder[i], file_name)
    
    if file_extension == '.csv':
        current_df = pd.read_csv(file_path, encoding='latin-1')
    elif file_extension == '.txt':
        current_df = pd.read_csv(file_path, sep='|')
    else:
        continue

    # --- KEY LOGIC FOR INTER-FILE DEDUPLICATION ---
    
    # Concatenate the current file's data with all previously processed data
    # (Do NOT use ignore_index=True here, we need separate indices for now)
    
    if final_unique_dfs:
        # Create a temporary DataFrame of ALL data processed so far
        all_prior_data = pd.concat(final_unique_dfs)
        
        # Check the current_df against all prior data. 
        # We only look at the columns that contain the actual data (excluding the index).
        data_columns = current_df.columns
        
        # Identify rows in the current file that are NOT duplicates of PRIOR files
        # The 'indicator=True' is used to identify the source of the merge
        merged = pd.merge(
            current_df, 
            all_prior_data, 
            on=list(data_columns), # Merge on all data columns
            how='left', 
            indicator=True
        )
        
        # Rows in the current file that are *only* in the 'left' (current_df) are unique
        unique_to_current_file = merged[merged['_merge'] == 'left_only'].drop(columns='_merge')
        
        # Append the unique data (which includes any intra-file duplicates)
        final_unique_dfs.append(unique_to_current_file)
    else:
        # The first file is added as is (it has no prior files to check against)
        final_unique_dfs.append(current_df)


# 3. Final Concatenation
if final_unique_dfs:
    # Concatenate the final list of DataFrames to produce the result
    final_df = pd.concat(final_unique_dfs, ignore_index=True)

    print("✅ Successfully merged and removed ONLY inter-file duplicates.")
    print("\nFinal DataFrame head (includes intra-file duplicates):")
else:
    print("❌ No valid files were read. The final DataFrame is empty.")
# Out:
# ✅ Successfully merged and removed ONLY inter-file duplicates.
#
# Final DataFrame head (includes intra-file duplicates):

# %%
final_df
# Out:
#         PATIENT_STUDY_ID  ACCESSION_NUMBER ORG_CODE  INTERNAL_EXAM_ID  \
# 0             4334585594          68008794   HMTHIC          81307232
# 1             4334585594          68008794   HMTHIC          81307232
# 2             4334453170          61626590   MWHOAK          84088623
# 3             4334453170          61762111   MWHOAK          84022507
# 4             4334453170          61305273   MWHOAK          85746212
# ...                  ...               ...      ...               ...
# 505398        4333020539         450787967   MWHMNV          73951489
# 505399        4333076287         450143208   MWHMNV          73422035
# 505400        4333076287         450143208   MWHMNV          73422035
# 505401        4333710261         459288483   MWHMNV          72569626
# 505402        4333710261         459288483   MWHMNV          72569626
#
#         PATIENT_ID                   COMPOSITION_NAME FINDING_LOCATION  \
# 0         45497467  Heterogeneously dense (51% - 75%)              NaN
# 1         45497467  Heterogeneously dense (51% - 75%)              NaN
# 2          2505470  Heterogeneously dense (51% - 75%)              NaN
# 3          2505470  Heterogeneously dense (51% - 75%)              NaN
# 4          2505470  Heterogeneously dense (51% - 75%)              NaN
# ...            ...                                ...              ...
# 505398     9719418  Heterogeneously dense (51% - 75%)              NaN
# 505399     3044268  Heterogeneously dense (51% - 75%)              NaN
# 505400     3044268  Heterogeneously dense (51% - 75%)              NaN
# 505401     1130178  Heterogeneously dense (51% - 75%)              NaN
# 505402     1130178  Heterogeneously dense (51% - 75%)              NaN
#
#                                       FINDING_CATEGORY  \
# 0                                         1 - Negative
# 1                                         1 - Negative
# 2                                   2 - Benign finding
# 3       3 - Probably benign - short interval follow-up
# 4               0 - Need additional imaging evaluation
# ...                                                ...
# 505398                              2 - Benign finding
# 505399                              2 - Benign finding
# 505400                              2 - Benign finding
# 505401                              2 - Benign finding
# 505402                              2 - Benign finding
#
#                                         FINDING_REC EXAM_COMPLETED_DATE
# 0                       N-Normal interval follow-up          12/08/2020
# 1                       N-Normal interval follow-up          12/08/2020
# 2                       N-Normal interval follow-up          07/11/2020
# 3       F-Follow-up at short interval (1-11 months)          02/04/2020
# 4                          P-Additional projections          01/18/2020
# ...                                             ...                 ...
# 505398                  N-Normal interval follow-up          12/30/2022
# 505399                  N-Normal interval follow-up          12/09/2022
# 505400                  N-Normal interval follow-up          12/09/2022
# 505401                  N-Normal interval follow-up          12/20/2022
# 505402                  N-Normal interval follow-up          12/20/2022
#
# [505403 rows x 10 columns]

# %%
final_df['EXAM_COMPLETED_DATE'] = pd.to_datetime(final_df['EXAM_COMPLETED_DATE'], format='%m/%d/%Y')
final_df['EXAM_COMPLETED_DATE'] = final_df['EXAM_COMPLETED_DATE'].dt.strftime('%Y-%m-%d')

# %%
final_df.sort_values(by=['PATIENT_STUDY_ID', 'EXAM_COMPLETED_DATE', 'ACCESSION_NUMBER', "FINDING_CATEGORY"], ascending=[True, True, False, True], inplace=True, ignore_index=True)

# %%
final_df.dropna(subset=['COMPOSITION_NAME', 'FINDING_LOCATION', 'FINDING_CATEGORY', 'FINDING_REC'], how='all', inplace=True)

# %% [markdown]
# #### <span style="color: blue;">Remove duplicated entries, add a column marked how many duplicates </span>
#
# **Before drop duplicate = <span style="color: blue;">final_df</span> , after drop duplicate = <span style="color: blue;">unique_df</span>**

# %%
unique_df = final_df.copy()

# %%
unique_df['duplicate_count'] = unique_df.groupby(unique_df.columns.tolist(), dropna=False).transform('size')

# %%
unique_df = unique_df.drop_duplicates(subset=unique_df.columns.tolist(), keep = 'first').reset_index(drop = True)

# %%
unique_extract_cols = extract_cols + ['duplicate_count']

# %%
final_df[extract_cols]
# Out:
#         PATIENT_STUDY_ID  ACCESSION_NUMBER                   COMPOSITION_NAME  \
# 0             4330000534          78048053  Heterogeneously dense (51% - 75%)
# 1             4330000534          78048053  Heterogeneously dense (51% - 75%)
# 2             4330000534          64787403  Heterogeneously dense (51% - 75%)
# 3             4330000534          64787403  Heterogeneously dense (51% - 75%)
# 5             4330000534          63280481  Heterogeneously dense (51% - 75%)
# ...                  ...               ...                                ...
# 505398        4339988199          61697072  Heterogeneously dense (51% - 75%)
# 505399        4339988199          67718778  Heterogeneously dense (51% - 75%)
# 505400        4339988199          67718778  Heterogeneously dense (51% - 75%)
# 505401        4339988199         452549960  Heterogeneously dense (51% - 75%)
# 505402        4339988199         452549960  Heterogeneously dense (51% - 75%)
#
#        FINDING_LOCATION                        FINDING_CATEGORY  \
# 0                   NaN                      2 - Benign finding
# 1                   NaN                      2 - Benign finding
# 2                   NaN  0 - Need additional imaging evaluation
# 3                   NaN  0 - Need additional imaging evaluation
# 5                   NaN                      2 - Benign finding
# ...                 ...                                     ...
# 505398              NaN                      2 - Benign finding
# 505399              NaN                      2 - Benign finding
# 505400              NaN                      2 - Benign finding
# 505401              NaN                            1 - Negative
# 505402              NaN                            1 - Negative
#
#                         FINDING_REC EXAM_COMPLETED_DATE
# 0       N-Normal interval follow-up          2018-03-28
# 1       N-Normal interval follow-up          2018-03-28
# 2          P-Additional projections          2019-05-18
# 3          P-Additional projections          2019-05-18
# 5       N-Normal interval follow-up          2019-06-20
# ...                             ...                 ...
# 505398  N-Normal interval follow-up          2020-02-21
# 505399  N-Normal interval follow-up          2021-02-25
# 505400  N-Normal interval follow-up          2021-02-25
# 505401  N-Normal interval follow-up          2022-03-01
# 505402  N-Normal interval follow-up          2022-03-01
#
# [458861 rows x 7 columns]

# %%
unique_df[unique_extract_cols]
# Out:
#         PATIENT_STUDY_ID  ACCESSION_NUMBER  \
# 0             4330000534          78048053
# 1             4330000534          64787403
# 2             4330000534          63280481
# 3             4330000534          60228678
# 4             4330000534          60228678
# ...                  ...               ...
# 270644        4339982047         450915296
# 270645        4339988199          65403287
# 270646        4339988199          61697072
# 270647        4339988199          67718778
# 270648        4339988199         452549960
#
#                             COMPOSITION_NAME FINDING_LOCATION  \
# 0          Heterogeneously dense (51% - 75%)              NaN
# 1          Heterogeneously dense (51% - 75%)              NaN
# 2          Heterogeneously dense (51% - 75%)              NaN
# 3          Heterogeneously dense (51% - 75%)              NaN
# 4          Heterogeneously dense (51% - 75%)              NaN
# ...                                      ...              ...
# 270644     Heterogeneously dense (51% - 75%)              NaN
# 270645  Scattered fibroglandular (25% - 50%)              NaN
# 270646     Heterogeneously dense (51% - 75%)              NaN
# 270647     Heterogeneously dense (51% - 75%)              NaN
# 270648     Heterogeneously dense (51% - 75%)              NaN
#
#                               FINDING_CATEGORY                  FINDING_REC  \
# 0                           2 - Benign finding  N-Normal interval follow-up
# 1       0 - Need additional imaging evaluation     P-Additional projections
# 2                           2 - Benign finding  N-Normal interval follow-up
# 3       0 - Need additional imaging evaluation     P-Additional projections
# 4                                 1 - Negative  N-Normal interval follow-up
# ...                                        ...                          ...
# 270644                      2 - Benign finding  N-Normal interval follow-up
# 270645                            1 - Negative  N-Normal interval follow-up
# 270646                      2 - Benign finding  N-Normal interval follow-up
# 270647                      2 - Benign finding  N-Normal interval follow-up
# 270648                            1 - Negative  N-Normal interval follow-up
#
#        EXAM_COMPLETED_DATE  duplicate_count
# 0               2018-03-28                2
# 1               2019-05-18                2
# 2               2019-06-20                2
# 3               2020-06-01                1
# 4               2020-06-01                1
# ...                    ...              ...
# 270644          2022-10-12                2
# 270645          2018-11-28                2
# 270646          2020-02-21                2
# 270647          2021-02-25                2
# 270648          2022-03-01                2
#
# [270649 rows x 8 columns]

# %%
# output_file = os.path.join("../Data/", study, "Cleaned", file + ".xlsx")
# final_df[extract_cols].to_excel(output_file, index=False)

output_file = os.path.join("../Data/", study, "Cleaned", file + ".xlsx")
unique_df[unique_extract_cols].to_excel(output_file, index=False)
# Out:
# <ipython-input-31-698a1692f047>:5: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.7' currently installed).
#   unique_df[unique_extract_cols].to_excel(output_file, index=False)
